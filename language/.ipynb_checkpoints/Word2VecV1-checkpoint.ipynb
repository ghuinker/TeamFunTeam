# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import numpy as np
import matplotlib.pyplot as plt
from string import punctuation

DICTIONARYSIZE = 5000
MIDDLELAYERSIZE = DICTIONARYSIZE//40
#Set to none for no limit
SKIPWINDOW = 2
DATATEXT = 'lst2.txt'

# %%
model = Sequential()
model.add(Dense(input_dim=DICTIONARYSIZE, units = MIDDLELAYERSIZE, activation = "relu"))
model.add(Dense(units = DICTIONARYSIZE, activation = "softmax"))

sgd = SGD()
model.compile(loss="categorical_crossentropy",
             optimizer = sgd,
             metrics = ['accuracy'])

# %%
#Clean data set
def clean(lines):
    ret = []
    count = {}
    for line in lines:
        line = line.strip()
        split = line.split()
        if(len(split) == 0): continue
#         #These lines are specific to the Hamlet data set. Add code for lines to disregard
#         if(split[0].isupper()): continue
#         if(split[0] == "enter"): continue
        for word in split:
            word = word.lower()
            if word[-1] in punctuation:
                word = word[:-1]
            if len(word) == 0: continue
            if word[0] in punctuation:
                word = word[1:]
            if len(word) == 0: continue
            ret.append(word)
            if word in count.keys():
                count[word] += 1
            else:
                count[word] = 1
            
    return ret, count

lines = open(DATATEXT,'r').readlines()
wordList, count = clean(lines)

indexToWord = list(set(wordList))
print(indexToWord[:10])

#Construct word-to-index dictionary
wordToIndex = {indexToWord[i]:i for i in range(len(indexToWord))}
# Out:
# ['expectation', 'inch', 'letters', 'pigeons', 'disintegration', 'motherland', 'assess', 'obummer', 'removal', 'portrays']

# %%
#(Duplication test)
for i in range(-100,-1):
    if (i%len(indexToWord)) != wordToIndex[indexToWord[i]]:
        print(i)

# %%
#Construct word-to-vector (one-hot) and vector-to-word (one-hot) dictionary
#The "hot" one will be indexed by popularity
wordToVector = {}
zeroVector = [0 for _ in range(DICTIONARYSIZE)]
#First sort word-to-index by word popularity
wordsByPopularityDoubles = sorted(count.items(), key = lambda x:x[1], reverse = True)
wordsByPopularity = [wordsByPopularityDoubles[i][0] for i in range(len(wordsByPopularityDoubles))]

for i in range(DICTIONARYSIZE):
    vec = zeroVector.copy()
    vec[i] = 1
    wordToVector[wordsByPopularity[i]] = vec

# %%
print("Most popular words:\n" + str(wordsByPopularity[:100]))
print(str(len(wordsByPopularity)) + " words total.")
print("Least popular word to be considered: " + str(wordsByPopularityDoubles[DICTIONARYSIZE]))
# Out:
# Most popular words:
# ['the', 'to', 'and', 'a', 'of', 'i', 'is', 'that', 'in', 'it', 'you', 'for', 'they', 'are', 'with', 'on', 'be', 'this', 'have', 'was', 'but', 'not', 'he', 'people', 'as', 'just', 'like', 'their', 'all', 'we', 'or', 'them', 'if', 'my', 'so', 'what', 'from', 'about', 'your', "it's", 'at', 'out', 'would', 'by', 'who', 'an', "don't", 'do', 'me', 'get', 'can', 'when', 'think', 'up', 'how', 'because', 'our', 'no', 'his', 'know', 'will', 'being', 'there', 'has', 'want', 'even', 'right', 'her', 'some', 'were', 'one', 'now', 'make', "i'm", 'these', 'she', 'going', 'more', 'only', 'trump', 'go', 'had', 'why', 'kids', 'then', 'him', 'fucking', 'really', 'over', 'school', 'could', 'take', 'much', "that's", 'us', 'back', 'any', 'other', 'see', 'good']
# 9484 words total.
# Least popular word to be considered: ('wearer', 3)

# %%
#Create training arrays (Skip-gram)
#Currently creates the same batch every call
#May be stochastic in the future
def generate_batch():
    x_train = []
    y_train = []
    #Start the moving window. Windex is the index of the center of the window.
    #OPTIMIZE: Use np arrays
    #OPTIMIZE: Implement mini-batch features shown in the word2vec tutorial
    for windex in range(SKIPWINDOW, len(wordList) - SKIPWINDOW):
        centerWord = wordList[windex]
        #OPTIMIZE replace this lookup using a nice dictionary OOH OR A NUMPY ARRAY BOOLEAN THING
        if not (centerWord in wordToVector.keys()): continue
        for contex in range(windex-SKIPWINDOW-1, windex+SKIPWINDOW):
            contextWord = wordList[contex]
            #Skip the center word (it is a skip-gram after all...)
            if contex == windex: continue
            #OPTIMIZE replace this lookup using a nice dictionary
            if not (contextWord in wordToVector.keys()): continue
            x_train.append(wordToVector[wordList[windex]])
            y_train.append(wordToVector[wordList[contex]])
    return np.array(x_train), np.array(y_train)

# %%
def vectorToWord(vector):
    for i in range(len(vector)):
        if(vector[i]==1):
            return wordsByPopularity[i]

# %%
x_train, y_train = generate_batch()

# %%
print("y_train|x_train")
for i in range(10):
    print(vectorToWord(x_train[i]) + "|" + vectorToWord(y_train[i]))
print("Total training vectors: " + str(len(x_train)))
# Out:
# y_train|x_train
# fuck|clear
# fuck|what
# fuck|the
# fuck|did
# did|what
# did|the
# did|fuck
# did|you
# you|the
# you|fuck
# Total training vectors: 544333

# %%
model.fit(x_train, y_train, epochs = 100, batch_size = 32)

# %%
for i in range(DICTIONARYSIZE):
    a = model.predict(np.array([wordToVector[wordsByPopularity[i]]]))[0]
    printConfidence(a)
# Out:
# 1.17%: the
# 1.14%: are
# 1.13%: coming
# 1.11%: british
# 1.05%: and
# 1.04%: to
# 1.03%: of
# 1.02%: you
# 1.03%: my
# 1.01%: it
# 1.01%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.0%: me
# 1.01%: be
# 1.0%: him
# 1.0%: so
# 1.02%: have
# 1.01%: we
# 1.0%: no
# 1.01%: do
# 1.0%: all
# 1.0%: shall
# 1.0%: thou
# 1.0%: hamlet
# 1.01%: there
# 1.0%: sir
# 1.0%: go
# 1.0%: well
# 1.0%: then
# 1.01%: which
# 1.01%: such
# 1.0%: upon
# 1.0%: thee
# 1.01%: say
# 1.2%: the
# 1.12%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.02%: of
# 1.02%: you
# 1.0%: my
# 1.01%: a
# 1.01%: it
# 1.02%: his
# 1.02%: not
# 1.0%: with
# 1.01%: me
# 1.02%: he
# 1.02%: lord
# 1.0%: will
# 1.01%: we
# 1.0%: no
# 1.01%: on
# 1.01%: come
# 1.0%: most
# 1.0%: there
# 1.0%: first
# 1.0%: then
# 1.0%: which
# 1.0%: very
# 1.0%: give
# 1.0%: some
# 1.0%: here
# 1.0%: say
# 1.01%: much
# 1.01%: father
# 1.16%: the
# 1.13%: are
# 1.12%: coming
# 1.11%: british
# 1.07%: and
# 1.05%: to
# 1.05%: of
# 1.03%: you
# 1.03%: my
# 1.02%: that
# 1.01%: is
# 1.01%: his
# 1.02%: with
# 1.02%: me
# 1.03%: he
# 1.01%: be
# 1.01%: lord
# 1.0%: so
# 1.04%: have
# 1.05%: we
# 1.03%: no
# 1.0%: do
# 1.03%: on
# 1.01%: by
# 1.02%: come
# 1.02%: thou
# 1.01%: from
# 1.02%: hamlet
# 1.04%: there
# 1.0%: sir
# 1.02%: go
# 1.02%: well
# 1.01%: us
# 1.01%: first
# 1.04%: then
# 1.0%: know
# 1.02%: enter
# 1.02%: hath
# 1.04%: which
# 1.03%: such
# 1.02%: upon
# 1.04%: say
# 1.02%: father
# 1.19%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.0%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: not
# 1.0%: this
# 1.0%: lord
# 1.15%: the
# 1.15%: are
# 1.13%: coming
# 1.1%: british
# 1.07%: and
# 1.06%: to
# 1.05%: of
# 1.03%: you
# 1.05%: my
# 1.01%: it
# 1.02%: i
# 1.04%: that
# 1.04%: is
# 1.02%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.01%: him
# 1.01%: so
# 1.04%: have
# 1.03%: we
# 1.01%: no
# 1.02%: do
# 1.0%: on
# 1.01%: our
# 1.01%: all
# 1.0%: by
# 1.02%: shall
# 1.0%: come
# 1.02%: thou
# 1.01%: from
# 1.02%: hamlet
# 1.02%: there
# 1.01%: sir
# 1.02%: go
# 1.02%: well
# 1.0%: us
# 1.02%: then
# 1.01%: enter
# 1.01%: hath
# 1.02%: which
# 1.0%: why
# 1.02%: such
# 1.02%: upon
# 1.01%: thee
# 1.03%: say
# 1.18%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.04%: and
# 1.03%: to
# 1.02%: of
# 1.02%: you
# 1.02%: my
# 1.0%: a
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: with
# 1.0%: be
# 1.0%: have
# 1.0%: we
# 1.15%: the
# 1.15%: are
# 1.13%: coming
# 1.1%: british
# 1.07%: and
# 1.06%: to
# 1.05%: of
# 1.03%: you
# 1.05%: my
# 1.01%: it
# 1.02%: i
# 1.04%: that
# 1.04%: is
# 1.02%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.01%: him
# 1.01%: so
# 1.04%: have
# 1.03%: we
# 1.02%: no
# 1.02%: do
# 1.0%: on
# 1.01%: our
# 1.01%: all
# 1.0%: by
# 1.02%: shall
# 1.0%: come
# 1.02%: thou
# 1.01%: from
# 1.02%: hamlet
# 1.02%: there
# 1.01%: sir
# 1.02%: go
# 1.02%: well
# 1.0%: us
# 1.02%: then
# 1.01%: enter
# 1.01%: hath
# 1.02%: which
# 1.0%: why
# 1.02%: such
# 1.02%: upon
# 1.01%: thee
# 1.03%: say
# 1.2%: the
# 1.13%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.01%: of
# 1.02%: you
# 1.01%: my
# 1.01%: a
# 1.0%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.0%: is
# 1.0%: his
# 1.01%: not
# 1.0%: me
# 1.0%: he
# 1.0%: lord
# 1.17%: the
# 1.11%: are
# 1.12%: coming
# 1.12%: british
# 1.07%: and
# 1.03%: to
# 1.05%: of
# 1.03%: you
# 1.01%: my
# 1.01%: that
# 1.03%: his
# 1.01%: not
# 1.02%: with
# 1.03%: me
# 1.05%: he
# 1.03%: lord
# 1.03%: have
# 1.05%: we
# 1.03%: no
# 1.05%: on
# 1.01%: by
# 1.04%: come
# 1.01%: thou
# 1.01%: from
# 1.02%: hamlet
# 1.01%: most
# 1.05%: there
# 1.02%: go
# 1.01%: well
# 1.01%: us
# 1.02%: first
# 1.05%: then
# 1.01%: know
# 1.03%: enter
# 1.03%: hath
# 1.05%: which
# 1.03%: such
# 1.02%: here
# 1.02%: upon
# 1.05%: say
# 1.0%: much
# 1.04%: father
# 1.2%: the
# 1.1%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.01%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.03%: his
# 1.02%: not
# 1.0%: with
# 1.02%: me
# 1.04%: he
# 1.03%: lord
# 1.0%: what
# 1.01%: will
# 1.02%: we
# 1.01%: no
# 1.03%: on
# 1.02%: come
# 1.0%: hamlet
# 1.02%: most
# 1.01%: there
# 1.01%: them
# 1.01%: first
# 1.01%: then
# 1.0%: know
# 1.01%: enter
# 1.01%: hath
# 1.01%: which
# 1.02%: very
# 1.01%: give
# 1.0%: such
# 1.01%: some
# 1.02%: here
# 1.01%: say
# 1.02%: much
# 1.03%: father
# 1.17%: the
# 1.14%: are
# 1.13%: coming
# 1.11%: british
# 1.05%: and
# 1.04%: to
# 1.03%: of
# 1.02%: you
# 1.03%: my
# 1.01%: it
# 1.01%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.0%: me
# 1.01%: be
# 1.0%: him
# 1.0%: so
# 1.01%: have
# 1.01%: we
# 1.0%: no
# 1.01%: do
# 1.0%: all
# 1.0%: shall
# 1.0%: thou
# 1.0%: hamlet
# 1.01%: there
# 1.0%: sir
# 1.0%: go
# 1.0%: well
# 1.0%: then
# 1.0%: which
# 1.0%: such
# 1.0%: upon
# 1.0%: thee
# 1.01%: say
# 1.19%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.04%: and
# 1.03%: to
# 1.02%: of
# 1.02%: you
# 1.02%: my
# 1.0%: a
# 1.0%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: not
# 1.0%: with
# 1.0%: be
# 1.0%: have
# 1.18%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.05%: and
# 1.04%: to
# 1.03%: of
# 1.02%: you
# 1.03%: my
# 1.01%: it
# 1.01%: i
# 1.02%: that
# 1.02%: is
# 1.0%: with
# 1.0%: me
# 1.0%: be
# 1.0%: him
# 1.0%: so
# 1.01%: have
# 1.01%: we
# 1.0%: no
# 1.0%: do
# 1.0%: there
# 1.0%: say
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.21%: the
# 1.1%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.0%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.05%: his
# 1.03%: not
# 1.0%: with
# 1.03%: me
# 1.05%: he
# 1.04%: lord
# 1.0%: what
# 1.02%: will
# 1.03%: we
# 1.01%: no
# 1.04%: on
# 1.03%: come
# 1.0%: how
# 1.0%: hamlet
# 1.03%: most
# 1.02%: there
# 1.01%: them
# 1.0%: us
# 1.02%: first
# 1.02%: then
# 1.01%: know
# 1.01%: enter
# 1.02%: hath
# 1.02%: which
# 1.02%: very
# 1.02%: give
# 1.0%: such
# 1.02%: some
# 1.03%: here
# 1.02%: say
# 1.0%: man
# 1.03%: much
# 1.04%: father
# 1.19%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.04%: and
# 1.03%: to
# 1.02%: of
# 1.02%: you
# 1.02%: my
# 1.0%: a
# 1.0%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: not
# 1.0%: with
# 1.0%: be
# 1.0%: have
# 1.2%: the
# 1.1%: are
# 1.11%: coming
# 1.14%: british
# 1.04%: and
# 1.01%: to
# 1.03%: of
# 1.02%: you
# 1.01%: a
# 1.04%: his
# 1.03%: not
# 1.0%: with
# 1.03%: me
# 1.05%: he
# 1.04%: lord
# 1.0%: what
# 1.0%: have
# 1.01%: will
# 1.03%: we
# 1.01%: no
# 1.04%: on
# 1.03%: come
# 1.0%: how
# 1.01%: hamlet
# 1.02%: most
# 1.02%: there
# 1.01%: them
# 1.0%: us
# 1.02%: first
# 1.02%: then
# 1.01%: know
# 1.01%: enter
# 1.02%: hath
# 1.02%: which
# 1.02%: very
# 1.02%: give
# 1.01%: such
# 1.02%: some
# 1.03%: here
# 1.02%: say
# 1.03%: much
# 1.04%: father
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.16%: the
# 1.15%: are
# 1.13%: coming
# 1.11%: british
# 1.06%: and
# 1.05%: to
# 1.04%: of
# 1.02%: you
# 1.04%: my
# 1.01%: it
# 1.02%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.0%: him
# 1.01%: so
# 1.02%: have
# 1.02%: we
# 1.01%: no
# 1.01%: do
# 1.0%: our
# 1.01%: all
# 1.0%: by
# 1.01%: shall
# 1.01%: thou
# 1.0%: from
# 1.01%: hamlet
# 1.01%: there
# 1.01%: sir
# 1.01%: go
# 1.01%: well
# 1.01%: then
# 1.0%: enter
# 1.0%: hath
# 1.01%: which
# 1.01%: such
# 1.01%: upon
# 1.0%: thee
# 1.01%: say
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.2%: the
# 1.1%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.01%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.04%: his
# 1.03%: not
# 1.0%: with
# 1.02%: me
# 1.04%: he
# 1.03%: lord
# 1.0%: what
# 1.01%: will
# 1.02%: we
# 1.01%: no
# 1.03%: on
# 1.02%: come
# 1.0%: how
# 1.0%: hamlet
# 1.02%: most
# 1.02%: there
# 1.01%: them
# 1.02%: first
# 1.02%: then
# 1.0%: know
# 1.01%: enter
# 1.01%: hath
# 1.02%: which
# 1.02%: very
# 1.02%: give
# 1.0%: such
# 1.01%: some
# 1.02%: here
# 1.01%: say
# 1.02%: much
# 1.03%: father
# 1.2%: the
# 1.13%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.01%: of
# 1.02%: you
# 1.01%: my
# 1.01%: a
# 1.0%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.0%: is
# 1.0%: his
# 1.01%: not
# 1.0%: me
# 1.0%: he
# 1.0%: lord
# 1.17%: the
# 1.11%: are
# 1.12%: coming
# 1.12%: british
# 1.07%: and
# 1.03%: to
# 1.05%: of
# 1.03%: you
# 1.02%: my
# 1.01%: that
# 1.03%: his
# 1.01%: not
# 1.02%: with
# 1.03%: me
# 1.05%: he
# 1.02%: lord
# 1.03%: have
# 1.05%: we
# 1.03%: no
# 1.05%: on
# 1.01%: by
# 1.04%: come
# 1.01%: thou
# 1.01%: from
# 1.03%: hamlet
# 1.01%: most
# 1.05%: there
# 1.02%: go
# 1.01%: well
# 1.01%: us
# 1.02%: first
# 1.05%: then
# 1.01%: know
# 1.03%: enter
# 1.03%: hath
# 1.05%: which
# 1.03%: such
# 1.02%: here
# 1.02%: upon
# 1.05%: say
# 1.0%: much
# 1.04%: father
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.18%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.05%: and
# 1.04%: to
# 1.03%: of
# 1.02%: you
# 1.03%: my
# 1.01%: it
# 1.01%: i
# 1.02%: that
# 1.02%: is
# 1.0%: with
# 1.0%: me
# 1.0%: be
# 1.0%: him
# 1.0%: so
# 1.01%: have
# 1.01%: we
# 1.0%: no
# 1.0%: do
# 1.0%: all
# 1.0%: shall
# 1.0%: hamlet
# 1.0%: there
# 1.0%: go
# 1.0%: well
# 1.0%: then
# 1.0%: which
# 1.0%: such
# 1.0%: say
# 1.17%: the
# 1.15%: are
# 1.13%: coming
# 1.11%: british
# 1.06%: and
# 1.05%: to
# 1.03%: of
# 1.02%: you
# 1.03%: my
# 1.01%: it
# 1.02%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.0%: him
# 1.0%: so
# 1.02%: have
# 1.01%: we
# 1.01%: no
# 1.01%: do
# 1.0%: all
# 1.01%: shall
# 1.0%: thou
# 1.0%: from
# 1.01%: hamlet
# 1.01%: there
# 1.0%: sir
# 1.01%: go
# 1.01%: well
# 1.01%: then
# 1.01%: which
# 1.01%: such
# 1.01%: upon
# 1.0%: thee
# 1.01%: say
# 1.14%: the
# 1.16%: are
# 1.13%: coming
# 1.1%: british
# 1.08%: and
# 1.07%: to
# 1.05%: of
# 1.03%: you
# 1.06%: my
# 1.01%: it
# 1.02%: i
# 1.04%: that
# 1.04%: is
# 1.02%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.01%: him
# 1.01%: so
# 1.04%: have
# 1.03%: we
# 1.02%: no
# 1.02%: do
# 1.0%: on
# 1.01%: our
# 1.02%: all
# 1.01%: by
# 1.02%: shall
# 1.0%: come
# 1.02%: thou
# 1.01%: from
# 1.02%: hamlet
# 1.03%: there
# 1.02%: sir
# 1.03%: go
# 1.02%: well
# 1.0%: us
# 1.03%: then
# 1.01%: enter
# 1.01%: hath
# 1.03%: which
# 1.0%: why
# 1.03%: such
# 1.02%: upon
# 1.02%: thee
# 1.03%: say
# 1.2%: the
# 1.11%: are
# 1.12%: coming
# 1.14%: british
# 1.03%: and
# 1.01%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.0%: it
# 1.03%: his
# 1.02%: not
# 1.0%: with
# 1.02%: me
# 1.03%: he
# 1.03%: lord
# 1.0%: what
# 1.01%: will
# 1.02%: we
# 1.01%: no
# 1.02%: on
# 1.02%: come
# 1.01%: most
# 1.01%: there
# 1.01%: them
# 1.01%: first
# 1.01%: then
# 1.0%: know
# 1.0%: enter
# 1.01%: hath
# 1.01%: which
# 1.01%: very
# 1.01%: give
# 1.01%: some
# 1.02%: here
# 1.01%: say
# 1.02%: much
# 1.02%: father
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.2%: the
# 1.12%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.02%: of
# 1.02%: you
# 1.01%: my
# 1.01%: a
# 1.0%: in
# 1.01%: it
# 1.0%: that
# 1.01%: his
# 1.01%: not
# 1.01%: me
# 1.01%: he
# 1.01%: lord
# 1.0%: will
# 1.0%: we
# 1.0%: on
# 1.0%: come
# 1.0%: father
# 1.2%: the
# 1.11%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.01%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.0%: it
# 1.03%: his
# 1.02%: not
# 1.0%: with
# 1.02%: me
# 1.04%: he
# 1.03%: lord
# 1.0%: what
# 1.01%: will
# 1.02%: we
# 1.01%: no
# 1.03%: on
# 1.02%: come
# 1.0%: hamlet
# 1.02%: most
# 1.01%: there
# 1.01%: them
# 1.01%: first
# 1.01%: then
# 1.0%: know
# 1.01%: enter
# 1.01%: hath
# 1.01%: which
# 1.02%: very
# 1.01%: give
# 1.0%: such
# 1.01%: some
# 1.02%: here
# 1.01%: say
# 1.02%: much
# 1.03%: father
# 1.17%: the
# 1.13%: are
# 1.12%: coming
# 1.12%: british
# 1.06%: and
# 1.04%: to
# 1.04%: of
# 1.03%: you
# 1.02%: my
# 1.0%: it
# 1.01%: that
# 1.0%: is
# 1.01%: his
# 1.0%: not
# 1.01%: with
# 1.01%: me
# 1.02%: he
# 1.0%: be
# 1.01%: lord
# 1.02%: have
# 1.03%: we
# 1.01%: no
# 1.02%: on
# 1.0%: by
# 1.01%: come
# 1.01%: thou
# 1.0%: from
# 1.01%: hamlet
# 1.02%: there
# 1.01%: go
# 1.01%: well
# 1.0%: us
# 1.0%: first
# 1.02%: then
# 1.01%: enter
# 1.01%: hath
# 1.02%: which
# 1.01%: such
# 1.01%: upon
# 1.02%: say
# 1.01%: father
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.2%: the
# 1.13%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.02%: of
# 1.02%: you
# 1.01%: my
# 1.01%: a
# 1.0%: in
# 1.01%: it
# 1.0%: i
# 1.0%: that
# 1.01%: his
# 1.01%: not
# 1.01%: me
# 1.01%: he
# 1.01%: lord
# 1.0%: will
# 1.0%: we
# 1.0%: on
# 1.17%: the
# 1.15%: are
# 1.13%: coming
# 1.11%: british
# 1.06%: and
# 1.05%: to
# 1.03%: of
# 1.02%: you
# 1.04%: my
# 1.01%: it
# 1.02%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.0%: him
# 1.0%: so
# 1.02%: have
# 1.01%: we
# 1.01%: no
# 1.01%: do
# 1.0%: all
# 1.01%: shall
# 1.0%: thou
# 1.0%: from
# 1.01%: hamlet
# 1.01%: there
# 1.0%: sir
# 1.01%: go
# 1.01%: well
# 1.01%: then
# 1.01%: which
# 1.01%: such
# 1.01%: upon
# 1.0%: thee
# 1.01%: say
# 1.2%: the
# 1.12%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.02%: of
# 1.02%: you
# 1.0%: my
# 1.01%: a
# 1.0%: it
# 1.02%: his
# 1.02%: not
# 1.0%: with
# 1.01%: me
# 1.02%: he
# 1.02%: lord
# 1.0%: what
# 1.01%: will
# 1.01%: we
# 1.0%: no
# 1.01%: on
# 1.01%: come
# 1.01%: most
# 1.0%: there
# 1.0%: them
# 1.0%: first
# 1.0%: then
# 1.0%: hath
# 1.0%: which
# 1.0%: very
# 1.0%: give
# 1.0%: some
# 1.01%: here
# 1.0%: say
# 1.01%: much
# 1.01%: father
# 1.15%: the
# 1.13%: are
# 1.12%: coming
# 1.11%: british
# 1.08%: and
# 1.05%: to
# 1.07%: of
# 1.03%: you
# 1.03%: my
# 1.03%: that
# 1.01%: is
# 1.01%: his
# 1.02%: with
# 1.03%: me
# 1.04%: he
# 1.01%: be
# 1.01%: lord
# 1.0%: so
# 1.05%: have
# 1.06%: we
# 1.04%: no
# 1.0%: do
# 1.04%: on
# 1.01%: by
# 1.03%: come
# 1.02%: thou
# 1.01%: from
# 1.03%: hamlet
# 1.06%: there
# 1.01%: sir
# 1.03%: go
# 1.02%: well
# 1.02%: us
# 1.02%: first
# 1.06%: then
# 1.0%: know
# 1.03%: enter
# 1.04%: hath
# 1.06%: which
# 1.04%: such
# 1.0%: here
# 1.03%: upon
# 1.06%: say
# 1.04%: father
# 1.19%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.04%: and
# 1.03%: to
# 1.02%: of
# 1.02%: you
# 1.02%: my
# 1.0%: a
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: not
# 1.0%: with
# 1.0%: be
# 1.0%: have
# 1.15%: the
# 1.15%: are
# 1.13%: coming
# 1.1%: british
# 1.08%: and
# 1.07%: to
# 1.05%: of
# 1.03%: you
# 1.05%: my
# 1.01%: it
# 1.02%: i
# 1.04%: that
# 1.04%: is
# 1.02%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.01%: him
# 1.01%: so
# 1.04%: have
# 1.03%: we
# 1.02%: no
# 1.02%: do
# 1.0%: on
# 1.01%: our
# 1.01%: all
# 1.01%: by
# 1.02%: shall
# 1.0%: come
# 1.02%: thou
# 1.01%: from
# 1.02%: hamlet
# 1.02%: there
# 1.02%: sir
# 1.02%: go
# 1.02%: well
# 1.0%: us
# 1.02%: then
# 1.01%: enter
# 1.01%: hath
# 1.02%: which
# 1.0%: why
# 1.02%: such
# 1.02%: upon
# 1.02%: thee
# 1.03%: say
# 1.18%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.04%: and
# 1.03%: to
# 1.02%: of
# 1.02%: you
# 1.02%: my
# 1.0%: a
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: with
# 1.0%: be
# 1.0%: have
# 1.0%: we
# 1.17%: the
# 1.15%: are
# 1.13%: coming
# 1.11%: british
# 1.06%: and
# 1.05%: to
# 1.04%: of
# 1.02%: you
# 1.04%: my
# 1.01%: it
# 1.02%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.0%: him
# 1.01%: so
# 1.02%: have
# 1.02%: we
# 1.01%: no
# 1.01%: do
# 1.0%: our
# 1.01%: all
# 1.01%: shall
# 1.01%: thou
# 1.0%: from
# 1.01%: hamlet
# 1.01%: there
# 1.0%: sir
# 1.01%: go
# 1.01%: well
# 1.01%: then
# 1.0%: hath
# 1.01%: which
# 1.01%: such
# 1.01%: upon
# 1.0%: thee
# 1.01%: say
# 1.18%: the
# 1.13%: are
# 1.12%: coming
# 1.12%: british
# 1.05%: and
# 1.03%: to
# 1.03%: of
# 1.02%: you
# 1.02%: my
# 1.0%: it
# 1.01%: that
# 1.0%: is
# 1.01%: his
# 1.0%: not
# 1.01%: with
# 1.01%: me
# 1.02%: he
# 1.0%: be
# 1.01%: lord
# 1.01%: have
# 1.02%: we
# 1.01%: no
# 1.01%: on
# 1.0%: by
# 1.01%: come
# 1.0%: thou
# 1.01%: hamlet
# 1.02%: there
# 1.01%: go
# 1.0%: well
# 1.0%: us
# 1.0%: first
# 1.02%: then
# 1.01%: enter
# 1.01%: hath
# 1.02%: which
# 1.01%: such
# 1.01%: upon
# 1.02%: say
# 1.01%: father
# 1.14%: the
# 1.16%: are
# 1.13%: coming
# 1.1%: british
# 1.08%: and
# 1.07%: to
# 1.05%: of
# 1.03%: you
# 1.05%: my
# 1.01%: it
# 1.02%: i
# 1.04%: that
# 1.04%: is
# 1.02%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.01%: him
# 1.01%: so
# 1.04%: have
# 1.03%: we
# 1.02%: no
# 1.02%: do
# 1.0%: on
# 1.01%: our
# 1.02%: all
# 1.01%: by
# 1.02%: shall
# 1.0%: come
# 1.02%: thou
# 1.01%: from
# 1.02%: hamlet
# 1.03%: there
# 1.02%: sir
# 1.02%: go
# 1.02%: well
# 1.0%: us
# 1.03%: then
# 1.01%: enter
# 1.01%: hath
# 1.03%: which
# 1.0%: why
# 1.03%: such
# 1.02%: upon
# 1.02%: thee
# 1.03%: say
# 1.18%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.05%: and
# 1.04%: to
# 1.03%: of
# 1.02%: you
# 1.03%: my
# 1.01%: it
# 1.01%: i
# 1.02%: that
# 1.02%: is
# 1.0%: with
# 1.0%: me
# 1.0%: be
# 1.0%: him
# 1.0%: so
# 1.01%: have
# 1.01%: we
# 1.0%: no
# 1.0%: do
# 1.0%: there
# 1.0%: say
# 1.2%: the
# 1.12%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.01%: to
# 1.02%: of
# 1.02%: you
# 1.0%: my
# 1.01%: a
# 1.0%: it
# 1.02%: his
# 1.02%: not
# 1.0%: with
# 1.01%: me
# 1.02%: he
# 1.02%: lord
# 1.0%: what
# 1.01%: will
# 1.01%: we
# 1.0%: no
# 1.02%: on
# 1.01%: come
# 1.01%: most
# 1.01%: there
# 1.0%: them
# 1.01%: first
# 1.01%: then
# 1.0%: hath
# 1.01%: which
# 1.01%: very
# 1.01%: give
# 1.0%: some
# 1.01%: here
# 1.0%: say
# 1.01%: much
# 1.01%: father
# 1.18%: the
# 1.1%: are
# 1.11%: coming
# 1.13%: british
# 1.06%: and
# 1.02%: to
# 1.04%: of
# 1.03%: you
# 1.0%: my
# 1.0%: that
# 1.04%: his
# 1.02%: not
# 1.01%: with
# 1.03%: me
# 1.05%: he
# 1.04%: lord
# 1.02%: have
# 1.05%: we
# 1.03%: no
# 1.05%: on
# 1.01%: by
# 1.04%: come
# 1.01%: thou
# 1.0%: from
# 1.02%: hamlet
# 1.02%: most
# 1.04%: there
# 1.0%: them
# 1.01%: go
# 1.0%: well
# 1.01%: us
# 1.03%: first
# 1.04%: then
# 1.01%: know
# 1.02%: enter
# 1.03%: hath
# 1.04%: which
# 1.01%: very
# 1.0%: give
# 1.02%: such
# 1.01%: some
# 1.03%: here
# 1.01%: upon
# 1.04%: say
# 1.02%: much
# 1.05%: father
# 1.17%: the
# 1.14%: are
# 1.13%: coming
# 1.11%: british
# 1.06%: and
# 1.05%: to
# 1.04%: of
# 1.03%: you
# 1.03%: my
# 1.01%: it
# 1.01%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.01%: me
# 1.01%: he
# 1.01%: be
# 1.0%: so
# 1.02%: have
# 1.02%: we
# 1.01%: no
# 1.01%: do
# 1.01%: on
# 1.0%: all
# 1.0%: by
# 1.0%: shall
# 1.0%: come
# 1.01%: thou
# 1.0%: from
# 1.01%: hamlet
# 1.02%: there
# 1.0%: sir
# 1.01%: go
# 1.01%: well
# 1.02%: then
# 1.0%: enter
# 1.01%: hath
# 1.02%: which
# 1.01%: such
# 1.01%: upon
# 1.02%: say
# 1.18%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.04%: and
# 1.04%: to
# 1.02%: of
# 1.02%: you
# 1.03%: my
# 1.01%: it
# 1.01%: i
# 1.02%: that
# 1.01%: is
# 1.0%: with
# 1.0%: me
# 1.0%: be
# 1.0%: him
# 1.0%: so
# 1.01%: have
# 1.0%: we
# 1.0%: do
# 1.0%: say
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.16%: the
# 1.15%: are
# 1.13%: coming
# 1.11%: british
# 1.06%: and
# 1.05%: to
# 1.04%: of
# 1.03%: you
# 1.04%: my
# 1.01%: it
# 1.02%: i
# 1.03%: that
# 1.03%: is
# 1.01%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.0%: him
# 1.01%: so
# 1.03%: have
# 1.02%: we
# 1.01%: no
# 1.01%: do
# 1.0%: our
# 1.01%: all
# 1.0%: by
# 1.01%: shall
# 1.0%: come
# 1.01%: thou
# 1.0%: from
# 1.01%: hamlet
# 1.01%: there
# 1.01%: sir
# 1.01%: go
# 1.01%: well
# 1.01%: then
# 1.0%: enter
# 1.0%: hath
# 1.01%: which
# 1.01%: such
# 1.01%: upon
# 1.01%: thee
# 1.02%: say
# 1.21%: the
# 1.09%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.03%: of
# 1.02%: you
# 1.01%: a
# 1.05%: his
# 1.03%: not
# 1.0%: with
# 1.03%: me
# 1.05%: he
# 1.05%: lord
# 1.0%: what
# 1.02%: will
# 1.03%: we
# 1.02%: no
# 1.05%: on
# 1.03%: come
# 1.0%: how
# 1.01%: hamlet
# 1.03%: most
# 1.03%: there
# 1.02%: them
# 1.0%: us
# 1.03%: first
# 1.03%: then
# 1.01%: know
# 1.01%: enter
# 1.02%: hath
# 1.03%: which
# 1.03%: very
# 1.03%: give
# 1.01%: such
# 1.02%: some
# 1.04%: here
# 1.03%: say
# 1.0%: man
# 1.04%: much
# 1.05%: father
# 1.0%: clown
# 1.17%: the
# 1.14%: are
# 1.13%: coming
# 1.11%: british
# 1.05%: and
# 1.04%: to
# 1.03%: of
# 1.02%: you
# 1.03%: my
# 1.01%: it
# 1.01%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.0%: him
# 1.0%: so
# 1.01%: have
# 1.01%: we
# 1.0%: no
# 1.01%: do
# 1.0%: all
# 1.0%: shall
# 1.0%: thou
# 1.0%: hamlet
# 1.01%: there
# 1.0%: sir
# 1.0%: go
# 1.0%: well
# 1.0%: then
# 1.0%: which
# 1.0%: such
# 1.0%: upon
# 1.0%: thee
# 1.01%: say
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.2%: the
# 1.11%: are
# 1.12%: coming
# 1.14%: british
# 1.03%: and
# 1.01%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.0%: it
# 1.03%: his
# 1.02%: not
# 1.0%: with
# 1.02%: me
# 1.03%: he
# 1.03%: lord
# 1.0%: what
# 1.01%: will
# 1.02%: we
# 1.01%: no
# 1.03%: on
# 1.02%: come
# 1.0%: hamlet
# 1.02%: most
# 1.01%: there
# 1.01%: them
# 1.01%: first
# 1.01%: then
# 1.0%: know
# 1.0%: enter
# 1.01%: hath
# 1.01%: which
# 1.01%: very
# 1.01%: give
# 1.01%: some
# 1.02%: here
# 1.01%: say
# 1.02%: much
# 1.02%: father
# 1.18%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.04%: and
# 1.03%: to
# 1.02%: of
# 1.02%: you
# 1.02%: my
# 1.0%: a
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: not
# 1.0%: with
# 1.0%: be
# 1.0%: have
# 1.0%: we
# 1.2%: the
# 1.1%: are
# 1.11%: coming
# 1.14%: british
# 1.04%: and
# 1.01%: to
# 1.03%: of
# 1.03%: you
# 1.01%: a
# 1.04%: his
# 1.03%: not
# 1.01%: with
# 1.03%: me
# 1.05%: he
# 1.04%: lord
# 1.01%: have
# 1.01%: will
# 1.03%: we
# 1.02%: no
# 1.04%: on
# 1.0%: by
# 1.03%: come
# 1.01%: hamlet
# 1.02%: most
# 1.03%: there
# 1.01%: them
# 1.0%: go
# 1.0%: us
# 1.02%: first
# 1.03%: then
# 1.01%: know
# 1.01%: enter
# 1.02%: hath
# 1.03%: which
# 1.02%: very
# 1.01%: give
# 1.01%: such
# 1.02%: some
# 1.03%: here
# 1.0%: upon
# 1.03%: say
# 1.03%: much
# 1.04%: father
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.2%: the
# 1.13%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.02%: of
# 1.02%: you
# 1.01%: my
# 1.01%: a
# 1.0%: in
# 1.01%: it
# 1.0%: i
# 1.0%: that
# 1.01%: his
# 1.01%: not
# 1.01%: me
# 1.01%: he
# 1.01%: lord
# 1.0%: we
# 1.0%: on
# 1.17%: the
# 1.15%: are
# 1.13%: coming
# 1.11%: british
# 1.06%: and
# 1.05%: to
# 1.03%: of
# 1.02%: you
# 1.04%: my
# 1.01%: it
# 1.02%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.0%: him
# 1.01%: so
# 1.02%: have
# 1.01%: we
# 1.01%: no
# 1.01%: do
# 1.0%: all
# 1.01%: shall
# 1.0%: thou
# 1.0%: from
# 1.01%: hamlet
# 1.01%: there
# 1.0%: sir
# 1.01%: go
# 1.01%: well
# 1.01%: then
# 1.0%: hath
# 1.01%: which
# 1.01%: such
# 1.01%: upon
# 1.0%: thee
# 1.01%: say
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.2%: the
# 1.13%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.02%: of
# 1.02%: you
# 1.01%: my
# 1.01%: a
# 1.0%: in
# 1.01%: it
# 1.0%: i
# 1.0%: that
# 1.01%: his
# 1.01%: not
# 1.01%: me
# 1.01%: he
# 1.01%: lord
# 1.0%: will
# 1.0%: we
# 1.0%: on
# 1.19%: the
# 1.1%: are
# 1.11%: coming
# 1.13%: british
# 1.05%: and
# 1.01%: to
# 1.04%: of
# 1.03%: you
# 1.0%: a
# 1.04%: his
# 1.02%: not
# 1.01%: with
# 1.03%: me
# 1.05%: he
# 1.04%: lord
# 1.01%: have
# 1.0%: will
# 1.04%: we
# 1.02%: no
# 1.05%: on
# 1.0%: by
# 1.03%: come
# 1.0%: thou
# 1.0%: from
# 1.01%: hamlet
# 1.02%: most
# 1.04%: there
# 1.01%: them
# 1.01%: go
# 1.01%: us
# 1.02%: first
# 1.04%: then
# 1.01%: know
# 1.02%: enter
# 1.03%: hath
# 1.04%: which
# 1.01%: very
# 1.01%: give
# 1.02%: such
# 1.01%: some
# 1.03%: here
# 1.01%: upon
# 1.04%: say
# 1.02%: much
# 1.04%: father
# 1.2%: the
# 1.1%: are
# 1.11%: coming
# 1.13%: british
# 1.04%: and
# 1.01%: to
# 1.03%: of
# 1.02%: you
# 1.01%: a
# 1.03%: his
# 1.02%: not
# 1.0%: with
# 1.03%: me
# 1.04%: he
# 1.03%: lord
# 1.0%: have
# 1.01%: will
# 1.03%: we
# 1.01%: no
# 1.03%: on
# 1.02%: come
# 1.01%: hamlet
# 1.02%: most
# 1.02%: there
# 1.01%: them
# 1.0%: go
# 1.0%: us
# 1.02%: first
# 1.02%: then
# 1.0%: know
# 1.01%: enter
# 1.01%: hath
# 1.02%: which
# 1.01%: very
# 1.01%: give
# 1.01%: such
# 1.01%: some
# 1.02%: here
# 1.02%: say
# 1.02%: much
# 1.03%: father
# 1.15%: the
# 1.13%: are
# 1.12%: coming
# 1.1%: british
# 1.09%: and
# 1.06%: to
# 1.06%: of
# 1.03%: you
# 1.04%: my
# 1.03%: that
# 1.01%: is
# 1.01%: his
# 1.02%: with
# 1.02%: me
# 1.04%: he
# 1.01%: be
# 1.0%: lord
# 1.0%: so
# 1.05%: have
# 1.06%: we
# 1.03%: no
# 1.0%: do
# 1.04%: on
# 1.01%: by
# 1.03%: come
# 1.02%: thou
# 1.01%: from
# 1.03%: hamlet
# 1.05%: there
# 1.01%: sir
# 1.03%: go
# 1.02%: well
# 1.01%: us
# 1.01%: first
# 1.05%: then
# 1.0%: know
# 1.03%: enter
# 1.03%: hath
# 1.05%: which
# 1.04%: such
# 1.03%: upon
# 1.06%: say
# 1.03%: father
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.17%: the
# 1.14%: are
# 1.13%: coming
# 1.11%: british
# 1.05%: and
# 1.05%: to
# 1.03%: of
# 1.02%: you
# 1.03%: my
# 1.01%: it
# 1.02%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.0%: me
# 1.01%: be
# 1.0%: him
# 1.0%: so
# 1.02%: have
# 1.01%: we
# 1.0%: no
# 1.01%: do
# 1.0%: all
# 1.0%: shall
# 1.0%: thou
# 1.01%: hamlet
# 1.01%: there
# 1.0%: sir
# 1.01%: go
# 1.01%: well
# 1.01%: then
# 1.01%: which
# 1.01%: such
# 1.0%: upon
# 1.0%: thee
# 1.01%: say
# 1.21%: the
# 1.09%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.03%: of
# 1.02%: you
# 1.01%: a
# 1.05%: his
# 1.03%: not
# 1.0%: with
# 1.03%: me
# 1.05%: he
# 1.05%: lord
# 1.0%: what
# 1.02%: will
# 1.03%: we
# 1.02%: no
# 1.05%: on
# 1.03%: come
# 1.0%: how
# 1.01%: hamlet
# 1.03%: most
# 1.03%: there
# 1.02%: them
# 1.0%: us
# 1.03%: first
# 1.03%: then
# 1.01%: know
# 1.01%: enter
# 1.02%: hath
# 1.03%: which
# 1.03%: very
# 1.03%: give
# 1.01%: such
# 1.02%: some
# 1.04%: here
# 1.03%: say
# 1.0%: man
# 1.04%: much
# 1.05%: father
# 1.0%: clown
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.21%: the
# 1.1%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.0%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.04%: his
# 1.03%: not
# 1.0%: with
# 1.03%: me
# 1.05%: he
# 1.04%: lord
# 1.0%: what
# 1.02%: will
# 1.03%: we
# 1.01%: no
# 1.04%: on
# 1.03%: come
# 1.0%: how
# 1.0%: hamlet
# 1.03%: most
# 1.02%: there
# 1.01%: them
# 1.0%: us
# 1.02%: first
# 1.02%: then
# 1.01%: know
# 1.01%: enter
# 1.02%: hath
# 1.02%: which
# 1.02%: very
# 1.02%: give
# 1.0%: such
# 1.02%: some
# 1.03%: here
# 1.02%: say
# 1.0%: man
# 1.03%: much
# 1.04%: father
# 1.16%: the
# 1.15%: are
# 1.13%: coming
# 1.11%: british
# 1.06%: and
# 1.05%: to
# 1.04%: of
# 1.02%: you
# 1.04%: my
# 1.01%: it
# 1.02%: i
# 1.02%: that
# 1.02%: is
# 1.01%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.0%: him
# 1.01%: so
# 1.02%: have
# 1.02%: we
# 1.01%: no
# 1.01%: do
# 1.0%: our
# 1.01%: all
# 1.01%: shall
# 1.01%: thou
# 1.0%: from
# 1.01%: hamlet
# 1.01%: there
# 1.01%: sir
# 1.01%: go
# 1.01%: well
# 1.01%: then
# 1.0%: enter
# 1.0%: hath
# 1.01%: which
# 1.01%: such
# 1.01%: upon
# 1.0%: thee
# 1.01%: say
# 1.2%: the
# 1.1%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.0%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.04%: his
# 1.03%: not
# 1.0%: with
# 1.03%: me
# 1.04%: he
# 1.04%: lord
# 1.0%: what
# 1.02%: will
# 1.02%: we
# 1.01%: no
# 1.04%: on
# 1.02%: come
# 1.0%: how
# 1.0%: hamlet
# 1.02%: most
# 1.02%: there
# 1.01%: them
# 1.0%: us
# 1.02%: first
# 1.02%: then
# 1.01%: know
# 1.01%: enter
# 1.02%: hath
# 1.02%: which
# 1.02%: very
# 1.02%: give
# 1.0%: such
# 1.02%: some
# 1.03%: here
# 1.02%: say
# 1.0%: man
# 1.03%: much
# 1.03%: father
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.21%: the
# 1.1%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.0%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.04%: his
# 1.03%: not
# 1.0%: with
# 1.03%: me
# 1.05%: he
# 1.04%: lord
# 1.0%: what
# 1.02%: will
# 1.03%: we
# 1.01%: no
# 1.04%: on
# 1.03%: come
# 1.0%: how
# 1.0%: hamlet
# 1.03%: most
# 1.02%: there
# 1.01%: them
# 1.0%: us
# 1.02%: first
# 1.02%: then
# 1.01%: know
# 1.01%: enter
# 1.02%: hath
# 1.02%: which
# 1.02%: very
# 1.02%: give
# 1.0%: such
# 1.02%: some
# 1.03%: here
# 1.02%: say
# 1.0%: man
# 1.03%: much
# 1.04%: father
# 1.16%: the
# 1.12%: are
# 1.12%: coming
# 1.11%: british
# 1.08%: and
# 1.04%: to
# 1.06%: of
# 1.03%: you
# 1.02%: my
# 1.02%: that
# 1.03%: his
# 1.0%: not
# 1.02%: with
# 1.03%: me
# 1.05%: he
# 1.0%: be
# 1.02%: lord
# 1.04%: have
# 1.06%: we
# 1.04%: no
# 1.05%: on
# 1.01%: by
# 1.04%: come
# 1.02%: thou
# 1.01%: from
# 1.03%: hamlet
# 1.01%: most
# 1.06%: there
# 1.03%: go
# 1.02%: well
# 1.02%: us
# 1.02%: first
# 1.06%: then
# 1.01%: know
# 1.03%: enter
# 1.04%: hath
# 1.06%: which
# 1.04%: such
# 1.01%: here
# 1.03%: upon
# 1.06%: say
# 1.05%: father
# 1.21%: the
# 1.09%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.03%: of
# 1.02%: you
# 1.01%: a
# 1.05%: his
# 1.03%: not
# 1.0%: with
# 1.04%: me
# 1.06%: he
# 1.05%: lord
# 1.0%: what
# 1.02%: will
# 1.03%: we
# 1.02%: no
# 1.05%: on
# 1.03%: come
# 1.0%: how
# 1.01%: hamlet
# 1.03%: most
# 1.03%: there
# 1.02%: them
# 1.0%: us
# 1.03%: first
# 1.03%: then
# 1.01%: know
# 1.01%: enter
# 1.02%: hath
# 1.03%: which
# 1.03%: very
# 1.03%: give
# 1.01%: such
# 1.02%: some
# 1.04%: here
# 1.03%: say
# 1.0%: man
# 1.04%: much
# 1.05%: father
# 1.0%: clown
# 1.2%: the
# 1.12%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.02%: of
# 1.02%: you
# 1.0%: my
# 1.01%: a
# 1.0%: it
# 1.02%: his
# 1.02%: not
# 1.0%: with
# 1.01%: me
# 1.02%: he
# 1.02%: lord
# 1.0%: will
# 1.01%: we
# 1.0%: no
# 1.01%: on
# 1.01%: come
# 1.01%: most
# 1.0%: there
# 1.0%: them
# 1.0%: first
# 1.0%: then
# 1.0%: hath
# 1.0%: which
# 1.0%: very
# 1.0%: give
# 1.0%: some
# 1.01%: here
# 1.0%: say
# 1.01%: much
# 1.01%: father
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.14%: the
# 1.16%: are
# 1.13%: coming
# 1.1%: british
# 1.08%: and
# 1.07%: to
# 1.05%: of
# 1.03%: you
# 1.05%: my
# 1.01%: it
# 1.02%: i
# 1.04%: that
# 1.04%: is
# 1.02%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.01%: him
# 1.01%: so
# 1.04%: have
# 1.03%: we
# 1.02%: no
# 1.02%: do
# 1.0%: on
# 1.01%: our
# 1.02%: all
# 1.01%: by
# 1.02%: shall
# 1.0%: come
# 1.02%: thou
# 1.01%: from
# 1.02%: hamlet
# 1.03%: there
# 1.02%: sir
# 1.02%: go
# 1.02%: well
# 1.0%: us
# 1.03%: then
# 1.01%: enter
# 1.01%: hath
# 1.03%: which
# 1.0%: why
# 1.03%: such
# 1.02%: upon
# 1.02%: thee
# 1.03%: say
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.18%: the
# 1.14%: are
# 1.13%: coming
# 1.12%: british
# 1.05%: and
# 1.04%: to
# 1.03%: of
# 1.02%: you
# 1.03%: my
# 1.01%: it
# 1.01%: i
# 1.02%: that
# 1.02%: is
# 1.0%: with
# 1.0%: me
# 1.0%: be
# 1.0%: him
# 1.0%: so
# 1.01%: have
# 1.01%: we
# 1.0%: no
# 1.0%: do
# 1.0%: there
# 1.0%: say
# 1.2%: the
# 1.12%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.02%: of
# 1.02%: you
# 1.01%: my
# 1.01%: a
# 1.01%: it
# 1.0%: that
# 1.02%: his
# 1.01%: not
# 1.01%: me
# 1.01%: he
# 1.01%: lord
# 1.0%: will
# 1.0%: we
# 1.01%: on
# 1.0%: come
# 1.0%: most
# 1.0%: there
# 1.0%: very
# 1.0%: here
# 1.0%: much
# 1.0%: father
# 1.2%: the
# 1.1%: are
# 1.11%: coming
# 1.14%: british
# 1.03%: and
# 1.01%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.04%: his
# 1.03%: not
# 1.0%: with
# 1.03%: me
# 1.04%: he
# 1.04%: lord
# 1.0%: what
# 1.01%: will
# 1.02%: we
# 1.01%: no
# 1.03%: on
# 1.02%: come
# 1.0%: how
# 1.0%: hamlet
# 1.02%: most
# 1.02%: there
# 1.01%: them
# 1.0%: us
# 1.02%: first
# 1.02%: then
# 1.0%: know
# 1.01%: enter
# 1.01%: hath
# 1.02%: which
# 1.02%: very
# 1.02%: give
# 1.0%: such
# 1.01%: some
# 1.02%: here
# 1.02%: say
# 1.02%: much
# 1.03%: father
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.16%: the
# 1.12%: are
# 1.12%: coming
# 1.11%: british
# 1.08%: and
# 1.04%: to
# 1.06%: of
# 1.03%: you
# 1.02%: my
# 1.02%: that
# 1.02%: his
# 1.0%: not
# 1.02%: with
# 1.03%: me
# 1.05%: he
# 1.0%: be
# 1.02%: lord
# 1.04%: have
# 1.06%: we
# 1.03%: no
# 1.04%: on
# 1.01%: by
# 1.04%: come
# 1.02%: thou
# 1.01%: from
# 1.03%: hamlet
# 1.01%: most
# 1.05%: there
# 1.03%: go
# 1.02%: well
# 1.01%: us
# 1.02%: first
# 1.05%: then
# 1.01%: know
# 1.03%: enter
# 1.03%: hath
# 1.05%: which
# 1.04%: such
# 1.01%: here
# 1.03%: upon
# 1.06%: say
# 1.04%: father
# 1.2%: the
# 1.1%: are
# 1.11%: coming
# 1.13%: british
# 1.04%: and
# 1.01%: to
# 1.03%: of
# 1.03%: you
# 1.01%: a
# 1.04%: his
# 1.02%: not
# 1.01%: with
# 1.03%: me
# 1.05%: he
# 1.04%: lord
# 1.01%: have
# 1.01%: will
# 1.03%: we
# 1.02%: no
# 1.04%: on
# 1.0%: by
# 1.03%: come
# 1.01%: hamlet
# 1.02%: most
# 1.03%: there
# 1.01%: them
# 1.0%: go
# 1.0%: us
# 1.02%: first
# 1.03%: then
# 1.01%: know
# 1.01%: enter
# 1.02%: hath
# 1.03%: which
# 1.02%: very
# 1.01%: give
# 1.01%: such
# 1.01%: some
# 1.03%: here
# 1.0%: upon
# 1.03%: say
# 1.02%: much
# 1.04%: father
# 1.2%: the
# 1.11%: are
# 1.12%: coming
# 1.14%: british
# 1.03%: and
# 1.01%: to
# 1.02%: of
# 1.02%: you
# 1.01%: a
# 1.0%: it
# 1.03%: his
# 1.02%: not
# 1.0%: with
# 1.02%: me
# 1.03%: he
# 1.03%: lord
# 1.0%: what
# 1.01%: will
# 1.02%: we
# 1.01%: no
# 1.03%: on
# 1.02%: come
# 1.0%: hamlet
# 1.02%: most
# 1.01%: there
# 1.01%: them
# 1.01%: first
# 1.01%: then
# 1.0%: know
# 1.0%: enter
# 1.01%: hath
# 1.01%: which
# 1.01%: very
# 1.01%: give
# 1.0%: such
# 1.01%: some
# 1.02%: here
# 1.01%: say
# 1.02%: much
# 1.03%: father
# 1.18%: the
# 1.13%: are
# 1.13%: coming
# 1.12%: british
# 1.04%: and
# 1.03%: to
# 1.02%: of
# 1.02%: you
# 1.02%: my
# 1.0%: a
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.0%: not
# 1.0%: with
# 1.0%: me
# 1.01%: he
# 1.0%: be
# 1.0%: lord
# 1.01%: have
# 1.01%: we
# 1.0%: no
# 1.0%: on
# 1.0%: there
# 1.0%: then
# 1.0%: which
# 1.0%: say
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.15%: the
# 1.15%: are
# 1.13%: coming
# 1.1%: british
# 1.07%: and
# 1.06%: to
# 1.05%: of
# 1.03%: you
# 1.05%: my
# 1.01%: it
# 1.02%: i
# 1.03%: that
# 1.03%: is
# 1.01%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.01%: him
# 1.01%: so
# 1.03%: have
# 1.03%: we
# 1.01%: no
# 1.02%: do
# 1.0%: on
# 1.0%: our
# 1.01%: all
# 1.0%: by
# 1.01%: shall
# 1.0%: come
# 1.01%: thou
# 1.01%: from
# 1.02%: hamlet
# 1.02%: there
# 1.01%: sir
# 1.02%: go
# 1.02%: well
# 1.0%: us
# 1.02%: then
# 1.01%: enter
# 1.01%: hath
# 1.02%: which
# 1.02%: such
# 1.02%: upon
# 1.01%: thee
# 1.02%: say
# 1.15%: the
# 1.15%: are
# 1.13%: coming
# 1.1%: british
# 1.08%: and
# 1.07%: to
# 1.05%: of
# 1.03%: you
# 1.05%: my
# 1.01%: it
# 1.02%: i
# 1.04%: that
# 1.04%: is
# 1.02%: with
# 1.0%: me
# 1.0%: he
# 1.01%: be
# 1.01%: him
# 1.01%: so
# 1.04%: have
# 1.03%: we
# 1.02%: no
# 1.02%: do
# 1.0%: on
# 1.01%: our
# 1.01%: all
# 1.0%: by
# 1.02%: shall
# 1.0%: come
# 1.02%: thou
# 1.01%: from
# 1.02%: hamlet
# 1.02%: there
# 1.01%: sir
# 1.02%: go
# 1.02%: well
# 1.0%: us
# 1.02%: then
# 1.01%: enter
# 1.01%: hath
# 1.02%: which
# 1.0%: why
# 1.02%: such
# 1.02%: upon
# 1.01%: thee
# 1.03%: say
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.2%: the
# 1.12%: are
# 1.12%: coming
# 1.13%: british
# 1.03%: and
# 1.02%: to
# 1.02%: of
# 1.02%: you
# 1.0%: my
# 1.01%: a
# 1.0%: it
# 1.02%: his
# 1.02%: not
# 1.0%: with
# 1.01%: me
# 1.02%: he
# 1.02%: lord
# 1.0%: what
# 1.01%: will
# 1.01%: we
# 1.0%: no
# 1.01%: on
# 1.01%: come
# 1.01%: most
# 1.0%: there
# 1.0%: them
# 1.0%: first
# 1.0%: then
# 1.0%: hath
# 1.0%: which
# 1.0%: very
# 1.0%: give
# 1.0%: some
# 1.01%: here
# 1.0%: say
# 1.01%: much
# 1.01%: father
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord
# 1.19%: the
# 1.13%: are
# 1.13%: coming
# 1.13%: british
# 1.03%: and
# 1.03%: to
# 1.01%: of
# 1.02%: you
# 1.02%: my
# 1.01%: a
# 1.01%: in
# 1.01%: it
# 1.01%: i
# 1.01%: that
# 1.01%: is
# 1.0%: his
# 1.01%: not
# 1.0%: this
# 1.0%: but
# 1.0%: lord

# %%
a = model.predict(np.array([wordToVector["hamlet"]]))[0]
printConfidence(a)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-160-94136bbeaf2c> in <module>()
#       1 a = model.predict(np.array([wordToVector["hamlet"]]))[0]
# ----> 2 printConfidence(a)
#       3 print(a)
#
# NameError: name 'printConfidence' is not defined

# %%
def printConfidence(prediction):
    for i,confidence in enumerate(prediction):
        if confidence > 0.01:
            print(str(round((confidence * 100), 2)) + "%: " + wordsByPopularity[i])

# %%
#What is wrong with my training set?
print("y_train|x_train")
for i in range(len(y_train)):
    print(vectorToWord(y_train[i]) + "|" + vectorToWord(x_train[i]))
# Out:
# y_train|x_train
# clear|fuck
# what|fuck
# the|fuck
# did|fuck
# what|did
# the|did
# fuck|did
# you|did
# the|you
# fuck|you
# did|you
# just|you
# fuck|just
# did|just
# you|just
# fucking|just
# did|fucking
# you|fucking
# just|fucking
# say|fucking
# you|say
# just|say
# fucking|say
# about|say
# just|about
# fucking|about
# say|about
# me|about
# fucking|me
# say|me
# about|me
# you|me
# say|you
# about|you
# me|you
# little|you
# about|little
# me|little
# you|little
# little|have
# you|have
# have|you
# know|you
# have|know
# you|know
# i|know
# have|i
# you|i
# know|i
# know|top
# i|top
# of|top
# i|of
# top|of
# my|of
# top|my
# of|my
# class|my
# top|class
# of|class
# my|class
# in|class
# of|in
# my|in
# class|in
# the|in
# my|the
# class|the
# in|the
# the|and
# i’ve|and
# and|i’ve
# been|i’ve
# and|been
# i’ve|been
# i’ve|in
# been|in
# on|and
# i|and
# on|i
# and|i
# have|i
# and|have
# i|have
# over|have
# and|over
# i|over
# have|over
# am|i
# i|am
# i|in
# am|in
# in|and
# i’m|and
# and|i’m
# the|i’m
# and|the
# i’m|the
# top|the
# and|top
# i’m|top
# the|top
# the|in
# top|in
# the|in
# top|the
# in|the
# entire|the
# in|entire
# the|entire
# us|entire
# in|us
# the|us
# entire|us
# armed|us
# the|armed
# entire|armed
# us|armed
# us|you
# armed|you
# are|you
# armed|are
# you|are
# nothing|are
# you|nothing
# are|nothing
# to|nothing
# you|to
# are|to
# nothing|to
# me|to
# are|me
# nothing|me
# to|me
# but|me
# nothing|but
# to|but
# me|but
# just|but
# to|just
# me|just
# but|just
# another|just
# me|another
# but|another
# just|another
# just|i
# another|i
# will|i
# another|will
# i|will
# i|you
# will|you
# the|you
# will|the
# you|the
# fuck|the
# you|fuck
# the|fuck
# out|fuck
# you|out
# the|out
# fuck|out
# with|out
# the|with
# fuck|with
# out|with
# out|the
# with|the
# the|of
# which|of
# the|which
# of|which
# has|which
# of|has
# which|has
# never|has
# of|never
# which|never
# has|never
# been|never
# which|been
# has|been
# never|been
# seen|been
# has|seen
# never|seen
# been|seen
# before|seen
# never|before
# been|before
# seen|before
# on|before
# been|on
# seen|on
# before|on
# this|on
# seen|this
# before|this
# on|this
# this|my
# fucking|my
# my|fucking
# words|fucking
# my|words
# fucking|words
# you|words
# my|you
# fucking|you
# words|you
# think|you
# fucking|think
# words|think
# you|think
# you|think
# words|you
# you|you
# think|you
# can|you
# you|can
# think|can
# you|can
# get|can
# think|get
# you|get
# can|get
# away|get
# you|away
# can|away
# get|away
# with|away
# can|with
# get|with
# away|with
# saying|with
# get|saying
# away|saying
# with|saying
# that|saying
# away|that
# with|that
# saying|that
# shit|that
# with|shit
# saying|shit
# that|shit
# to|shit
# saying|to
# that|to
# shit|to
# me|to
# that|me
# shit|me
# to|me
# over|me
# shit|over
# to|over
# me|over
# the|over
# to|the
# me|the
# over|the
# over|think
# the|think
# again|think
# the|again
# think|again
# think|as
# again|as
# we|as
# again|we
# as|we
# as|i
# we|i
# am|i
# we|am
# i|am
# i|my
# am|my
# my|of
# of|the
# the|and
# your|and
# the|your
# and|your
# and|is
# your|is
# being|is
# your|being
# is|being
# is|right
# being|right
# now|right
# being|now
# right|now
# so|now
# right|so
# now|so
# you|so
# right|you
# now|you
# so|you
# better|you
# now|better
# so|better
# you|better
# you|for
# better|for
# the|for
# better|the
# for|the
# the|the
# the|that
# that|out
# the|out
# that|the
# out|the
# out|little
# the|little
# thing|little
# the|thing
# little|thing
# you|thing
# little|you
# thing|you
# call|you
# little|call
# thing|call
# you|call
# your|call
# thing|your
# you|your
# call|your
# life|your
# you|life
# call|life
# your|life
# you’re|life
# call|you’re
# your|you’re
# life|you’re
# fucking|you’re
# your|fucking
# life|fucking
# you’re|fucking
# dead|fucking
# life|dead
# you’re|dead
# fucking|dead
# kid|dead
# you’re|kid
# fucking|kid
# dead|kid
# i|kid
# fucking|i
# dead|i
# kid|i
# can|i
# dead|can
# kid|can
# i|can
# be|can
# kid|be
# i|be
# can|be
# be|and
# i|and
# and|i
# can|i
# and|can
# i|can
# kill|can
# and|kill
# i|kill
# can|kill
# you|kill
# i|you
# can|you
# kill|you
# in|you
# can|in
# kill|in
# you|in
# over|in
# kill|over
# you|over
# in|over
# that’s|and
# and|that’s
# just|that’s
# and|just
# that’s|just
# with|just
# and|with
# that’s|with
# just|with
# my|with
# that’s|my
# just|my
# with|my
# my|not
# only|not
# not|only
# am|only
# not|am
# only|am
# i|am
# not|i
# only|i
# am|i
# i|in
# in|but
# i|but
# but|i
# have|i
# but|have
# i|have
# i|to
# have|to
# the|to
# have|the
# to|the
# entire|the
# to|entire
# the|entire
# the|of
# entire|of
# the|of
# entire|the
# of|the
# of|states
# the|states
# states|and
# i|and
# and|i
# will|i
# and|will
# i|will
# use|will
# and|use
# i|use
# will|use
# it|use
# i|it
# will|it
# use|it
# to|it
# will|to
# use|to
# it|to
# its|to
# use|its
# it|its
# to|its
# full|its
# it|full
# to|full
# its|full
# its|to
# full|to
# to|your
# your|off
# the|off
# off|the
# face|the
# off|face
# the|face
# of|face
# off|of
# the|of
# face|of
# the|of
# the|the
# face|the
# of|the
# of|you
# the|you
# little|you
# the|little
# you|little
# shit|little
# you|shit
# little|shit
# if|shit
# you|if
# little|if
# shit|if
# only|if
# little|only
# shit|only
# if|only
# you|only
# shit|you
# if|you
# only|you
# could|you
# if|could
# only|could
# you|could
# have|could
# only|have
# you|have
# could|have
# could|what
# have|what
# what|your
# little|your
# your|little
# little|was
# about|was
# was|about
# to|about
# was|to
# about|to
# bring|to
# was|bring
# about|bring
# to|bring
# down|bring
# about|down
# to|down
# bring|down
# bring|you
# down|you
# maybe|you
# down|maybe
# you|maybe
# you|maybe
# you|you
# maybe|you
# would|you
# you|would
# maybe|would
# you|would
# have|would
# maybe|have
# you|have
# would|have
# would|your
# have|your
# fucking|your
# have|fucking
# your|fucking
# your|but
# fucking|but
# you|but
# fucking|you
# but|you
# but|you
# you|you
# didn’t|you
# you|didn’t
# you|didn’t
# and|didn’t
# you|and
# didn’t|and
# now|and
# you|now
# didn’t|now
# and|now
# you’re|now
# didn’t|you’re
# and|you’re
# now|you’re
# now|the
# you’re|the
# the|you
# you|i
# will|i
# i|will
# shit|will
# i|shit
# will|shit
# will|all
# shit|all
# over|all
# shit|over
# all|over
# you|over
# all|you
# over|you
# and|you
# all|and
# over|and
# you|and
# you|and
# over|you
# you|you
# and|you
# will|you
# you|will
# and|will
# you|will
# you|in
# will|in
# it|in
# will|it
# in|it
# you’re|it
# in|you’re
# it|you’re
# fucking|you’re
# in|fucking
# it|fucking
# you’re|fucking
# dead|fucking
# it|dead
# you’re|dead
# fucking|dead
# fucking|in
# dead|in
# in|over
# your|over
# in|your
# over|your
# over|to
# your|to
# the|to
# your|the
# to|the
# local|the
# to|local
# the|local
# police|local
# to|police
# the|police
# local|police
# and|police
# the|and
# local|and
# police|and
# the|and
# local|the
# police|the
# and|the
# fbi|the
# police|fbi
# and|fbi
# the|fbi
# why|fbi
# and|why
# the|why
# fbi|why
# as|why
# the|as
# fbi|as
# why|as
# there|as
# fbi|there
# why|there
# as|there
# are|there
# why|are
# as|are
# there|are
# there|death
# are|death
# death|in
# it|in
# death|it
# in|it
# and|it
# in|and
# it|and
# i|and
# in|i
# it|i
# and|i
# and|my
# i|my
# life|my
# i|life
# my|life
# my|i
# life|i
# will|i
# life|will
# i|will
# be|will
# i|be
# will|be
# the|to
# to|the
# the|the
# law|the
# the|law
# the|i
# law|i
# am|i
# law|am
# i|am
# going|am
# i|going
# am|going
# to|going
# i|to
# am|to
# going|to
# going|reddit
# to|reddit
# or|reddit
# to|or
# reddit|or
# your|or
# reddit|your
# or|your
# your|and
# i|name
# name|i
# will|i
# name|will
# i|will
# i|that
# will|that
# you|that
# will|you
# that|you
# be|you
# that|be
# you|be
# you|from
# be|from
# the|from
# be|the
# from|the
# entire|the
# from|entire
# the|entire
# entire|if
# they|if
# if|they
# if|to
# they|to
# not|to
# they|not
# to|not
# do|not
# to|do
# not|do
# this|do
# to|this
# not|this
# do|this
# i|this
# not|i
# do|i
# this|i
# will|i
# do|will
# this|will
# i|will
# name|will
# this|name
# i|name
# will|name
# reddit|name
# i|reddit
# will|reddit
# name|reddit
# in|reddit
# will|in
# name|in
# reddit|in
# the|in
# name|the
# reddit|the
# in|the
# same|the
# reddit|same
# in|same
# the|same
# same|i
# i|on
# on|against
# you|against
# on|you
# against|you
# for|you
# against|for
# you|for
# mental|for
# against|mental
# you|mental
# for|mental
# for|when
# mental|when
# the|when
# mental|the
# when|the
# police|the
# when|police
# the|police
# the|police
# when|the
# the|the
# police|the
# fbi|the
# the|fbi
# police|fbi
# the|fbi
# and|fbi
# police|and
# the|and
# fbi|and
# reddit|and
# the|reddit
# fbi|reddit
# and|reddit
# all|reddit
# fbi|all
# and|all
# reddit|all
# reddit|i
# all|i
# am|i
# all|am
# i|am
# going|am
# i|going
# am|going
# to|going
# i|to
# am|to
# going|to
# the|to
# am|the
# going|the
# to|the
# news|the
# going|news
# to|news
# the|news
# and|news
# to|and
# the|and
# news|and
# news|me
# and|me
# the|me
# and|the
# me|the
# news|the
# me|news
# the|news
# has|news
# me|has
# the|has
# news|has
# a|has
# the|a
# news|a
# has|a
# thing|a
# news|thing
# has|thing
# a|thing
# for|thing
# has|for
# a|for
# thing|for
# for|right
# now|right
# right|now
# and|now
# right|and
# now|and
# while|and
# right|while
# now|while
# and|while
# i|while
# now|i
# and|i
# while|i
# am|i
# and|am
# while|am
# i|am
# a|am
# while|a
# i|a
# am|a
# man|a
# i|man
# am|man
# a|man
# of|man
# am|of
# a|of
# man|of
# to|love
# love|to
# watch|to
# love|watch
# to|watch
# you|watch
# love|you
# to|you
# watch|you
# the|in
# in|the
# in|of
# the|of
# public|of
# the|public
# of|public
# of|here
# public|here
# is|here
# public|is
# here|is
# it|is
# here|it
# is|it
# your|it
# here|your
# is|your
# it|your
# last|your
# is|last
# it|last
# your|last
# chance|last
# it|chance
# your|chance
# last|chance
# give|chance
# your|give
# last|give
# chance|give
# me|give
# last|me
# chance|me
# give|me
# your|me
# chance|your
# give|your
# me|your
# full|your
# give|full
# me|full
# your|full
# legal|full
# me|legal
# your|legal
# full|legal
# name|legal
# your|name
# full|name
# legal|name
# give|name
# full|give
# legal|give
# name|give
# me|give
# legal|me
# name|me
# give|me
# your|me
# name|your
# give|your
# me|your
# your|give
# me|give
# give|me
# your|me
# give|your
# me|your
# your|these
# will|these
# these|will
# only|will
# these|only
# will|only
# be|only
# these|be
# will|be
# only|be
# used|be
# will|used
# only|used
# be|used
# and|used
# only|and
# be|and
# used|and
# i|and
# be|i
# used|i
# and|i
# and|on
# i|on
# my|on
# i|my
# on|my
# children|my
# on|children
# my|children
# in|children
# on|in
# my|in
# children|in
# in|against
# against|if
# you|if
# against|you
# if|you
# don't|you
# if|don't
# you|don't
# stop|don't
# if|stop
# you|stop
# don't|stop
# if|stop
# you|if
# don't|if
# stop|if
# you|if
# don't|you
# stop|you
# if|you
# want|you
# stop|want
# if|want
# you|want
# to|want
# if|to
# you|to
# want|to
# want|this
# to|this
# this|be
# be|for
# your|for
# be|your
# for|your
# own|your
# for|own
# your|own
# your|have
# own|have
# no|have
# own|no
# have|no
# idea|no
# have|idea
# no|idea
# the|idea
# have|the
# no|the
# idea|the
# idea|i
# the|i
# am|i
# the|am
# i|am
# i|of
# am|of
# if|of
# am|if
# of|if
# you|if
# of|you
# if|you
# truly|you
# of|truly
# if|truly
# you|truly
# knew|truly
# if|knew
# you|knew
# truly|knew
# me|knew
# you|me
# truly|me
# knew|me
# you|me
# truly|you
# knew|you
# me|you
# would|you
# knew|would
# me|would
# you|would
# have|would
# me|have
# you|have
# would|have
# never|have
# you|never
# would|never
# have|never
# started|never
# would|started
# have|started
# never|started
# this|started
# have|this
# never|this
# started|this
# if|this
# never|if
# started|if
# this|if
# you|if
# started|you
# this|you
# if|you
# have|you
# this|have
# if|have
# you|have
# a|have
# if|a
# you|a
# have|a
# have|this
# a|this
# is|this
# a|is
# this|is
# good|is
# this|good
# is|good
# if|good
# this|if
# is|if
# good|if
# you|if
# is|you
# good|you
# if|you
# if|a
# you|a
# a|even
# better|even
# a|better
# even|better
# even|need
# better|need
# them|need
# better|them
# need|them
# if|them
# need|if
# them|if
# you|if
# need|you
# them|you
# if|you
# if|on
# you|on
# on|a
# man|a
# on|man
# a|man
# of|man
# a|of
# man|of
# my|of
# a|my
# man|my
# of|my
# of|and
# my|and
# and|high
# as|high
# and|as
# high|as
# that's|as
# high|that's
# as|that's
# the|that's
# high|the
# as|the
# that's|the
# only|the
# as|only
# that's|only
# the|only
# way|only
# that's|way
# the|way
# only|way
# only|ever
# way|ever
# stop|ever
# way|stop
# ever|stop
# stop|came
# into|came
# came|into
# my|into
# came|my
# into|my
# into|to
# my|to
# bring|to
# my|bring
# to|bring
# me|bring
# to|me
# bring|me
# a|me
# to|a
# bring|a
# me|a
# me|of
# a|of
# of|and
# i|and
# and|i
# literally|i
# and|literally
# i|literally
# i|at
# literally|at
# her|at
# literally|her
# at|her
# and|her
# at|and
# her|and
# hit|and
# at|hit
# her|hit
# and|hit
# the|hit
# her|the
# and|the
# hit|the
# hit|of
# the|of
# of|out
# of|out
# out|of
# her|of
# out|her
# of|her
# hand|her
# out|hand
# of|hand
# her|hand
# she|hand
# of|she
# her|she
# hand|she
# started|she
# her|started
# hand|started
# she|started
# she|and
# started|and
# and|at
# me|at
# and|me
# at|me
# and|me
# at|and
# me|and
# i|and
# at|i
# me|i
# and|i
# and|the
# i|the
# door|the
# i|door
# the|door
# on|door
# the|on
# door|on
# her|on
# the|her
# door|her
# on|her
# i'm|her
# door|i'm
# on|i'm
# her|i'm
# so|i'm
# on|so
# her|so
# i'm|so
# i'm|right
# so|right
# now|right
# so|now
# right|now
# i|now
# right|i
# now|i
# don't|i
# right|don't
# now|don't
# i|don't
# know|don't
# now|know
# i|know
# don't|know
# what|know
# i|what
# don't|what
# know|what
# to|what
# don't|to
# know|to
# what|to
# do|to
# know|do
# what|do
# to|do
# i|do
# what|i
# to|i
# do|i
# didn't|i
# to|didn't
# do|didn't
# i|didn't
# mean|didn't
# do|mean
# i|mean
# didn't|mean
# to|mean
# i|to
# didn't|to
# mean|to
# do|to
# didn't|do
# mean|do
# to|do
# that|do
# mean|that
# to|that
# do|that
# to|that
# to|to
# do|to
# that|to
# my|to
# do|my
# that|my
# to|my
# to|but
# my|but
# i'm|but
# my|i'm
# but|i'm
# literally|i'm
# but|literally
# i'm|literally
# in|literally
# but|in
# i'm|in
# literally|in
# literally|from
# in|from
# the|from
# in|the
# from|the
# the|i
# feel|i
# i|feel
# like|feel
# i|like
# feel|like
# i'm|like
# i|i'm
# feel|i'm
# like|i'm
# going|i'm
# feel|going
# like|going
# i'm|going
# to|going
# like|to
# i'm|to
# going|to
# going|why
# to|why
# the|why
# to|the
# why|the
# fucking|the
# why|fucking
# the|fucking
# fuck|fucking
# why|fuck
# the|fuck
# fucking|fuck
# is|fuck
# the|is
# fucking|is
# fuck|is
# he|is
# fucking|he
# fuck|he
# is|he
# is|this
# he|this
# can't|this
# he|can't
# this|can't
# be|can't
# this|be
# can't|be
# can't|i'm
# be|i'm
# having|i'm
# be|having
# i'm|having
# a|having
# i'm|a
# having|a
# fucking|a
# i'm|fucking
# having|fucking
# a|fucking
# a|i
# fucking|i
# don't|i
# fucking|don't
# i|don't
# want|don't
# i|want
# don't|want
# to|want
# i|to
# don't|to
# want|to
# believe|to
# don't|believe
# want|believe
# to|believe
# the|believe
# want|the
# to|the
# believe|the
# world|the
# to|world
# believe|world
# the|world
# is|world
# believe|is
# the|is
# world|is
# so|is
# the|so
# world|so
# is|so
# is|i
# so|i
# want|i
# so|want
# i|want
# a|want
# i|a
# want|a
# want|to
# a|to
# believe|to
# a|believe
# to|believe
# in|believe
# to|in
# believe|in
# i|in
# to|i
# believe|i
# in|i
# want|i
# believe|want
# in|want
# i|want
# i|to
# want|to
# be|to
# want|be
# to|be
# president|be
# to|president
# be|president
# and|president
# to|and
# be|and
# president|and
# president|this
# and|this
# this|country
# i|country
# this|i
# country|i
# cannot|i
# country|cannot
# i|cannot
# fucking|cannot
# country|fucking
# i|fucking
# cannot|fucking
# deal|fucking
# i|deal
# cannot|deal
# fucking|deal
# with|deal
# cannot|with
# fucking|with
# deal|with
# this|with
# fucking|this
# deal|this
# with|this
# right|this
# deal|right
# with|right
# this|right
# now|right
# with|now
# this|now
# right|now
# it|now
# this|it
# right|it
# now|it
# wasn't|it
# right|wasn't
# now|wasn't
# it|wasn't
# supposed|wasn't
# now|supposed
# it|supposed
# wasn't|supposed
# to|supposed
# it|to
# wasn't|to
# supposed|to
# be|to
# wasn't|be
# supposed|be
# to|be
# like|be
# supposed|like
# to|like
# be|like
# this|like
# to|this
# be|this
# like|this
# i|this
# be|i
# like|i
# this|i
# thought|i
# like|thought
# this|thought
# i|thought
# he|thought
# this|he
# i|he
# thought|he
# was|he
# i|was
# thought|was
# he|was
# he|well
# was|well
# for|well
# was|for
# well|for
# well|this
# for|this
# is|this
# for|is
# this|is
# so|is
# this|so
# is|so
# is|shit
# so|shit
# my|shit
# so|my
# shit|my
# shit|came
# my|came
# into|came
# my|into
# came|into
# my|into
# came|my
# into|my
# my|to
# bring|to
# to|bring
# me|bring
# to|me
# bring|me
# a|me
# to|a
# bring|a
# me|a
# me|of
# a|of
# of|and
# i|and
# of|i
# and|i
# literally|i
# and|literally
# i|literally
# i|at
# literally|at
# her|at
# literally|her
# at|her
# and|her
# at|and
# her|and
# hit|and
# at|hit
# her|hit
# and|hit
# the|hit
# her|the
# and|the
# hit|the
# hit|of
# the|of
# of|out
# of|out
# of|of
# out|of
# her|of
# out|her
# of|her
# hand|her
# out|hand
# of|hand
# her|hand
# she|hand
# of|she
# her|she
# hand|she
# started|she
# her|started
# hand|started
# she|started
# she|and
# started|and
# and|at
# me|at
# and|me
# at|me
# and|me
# at|and
# me|and
# i|and
# at|i
# me|i
# and|i
# and|the
# i|the
# door|the
# i|door
# the|door
# on|door
# the|on
# door|on
# her|on
# the|her
# door|her
# on|her
# i'm|her
# door|i'm
# on|i'm
# her|i'm
# so|i'm
# on|so
# her|so
# i'm|so
# i'm|right
# so|right
# now|right
# so|now
# right|now
# i|now
# right|i
# now|i
# don't|i
# right|don't
# now|don't
# i|don't
# know|don't
# now|know
# i|know
# don't|know
# what|know
# i|what
# don't|what
# know|what
# to|what
# don't|to
# know|to
# what|to
# do|to
# know|do
# what|do
# to|do
# i|do
# what|i
# to|i
# do|i
# didn't|i
# to|didn't
# do|didn't
# i|didn't
# mean|didn't
# do|mean
# i|mean
# didn't|mean
# to|mean
# i|to
# didn't|to
# mean|to
# mean|on
# to|on
# reddit|on
# to|reddit
# on|reddit
# about|reddit
# on|about
# reddit|about
# reddit|a
# about|a
# a|with
# my|with
# a|my
# with|my
# with|but
# my|but
# i'm|but
# my|i'm
# but|i'm
# literally|i'm
# but|literally
# i'm|literally
# in|literally
# but|in
# i'm|in
# literally|in
# literally|from
# in|from
# from|at
# my|at
# from|my
# at|my
# job|my
# at|job
# my|job
# i|job
# at|i
# my|i
# job|i
# feel|i
# my|feel
# job|feel
# i|feel
# like|feel
# job|like
# i|like
# feel|like
# i'm|like
# i|i'm
# feel|i'm
# like|i'm
# going|i'm
# feel|going
# like|going
# i'm|going
# to|going
# like|to
# i'm|to
# going|to
# going|why
# to|why
# the|why
# to|the
# why|the
# fucking|the
# why|fucking
# the|fucking
# fuck|fucking
# why|fuck
# the|fuck
# fucking|fuck
# is|fuck
# the|is
# fucking|is
# fuck|is
# she|is
# fucking|she
# fuck|she
# is|she
# is|this
# she|this
# can't|this
# she|can't
# this|can't
# be|can't
# this|be
# can't|be
# can't|i'm
# be|i'm
# having|i'm
# be|having
# i'm|having
# a|having
# i'm|a
# having|a
# fucking|a
# i'm|fucking
# having|fucking
# a|fucking
# a|i
# fucking|i
# don't|i
# fucking|don't
# i|don't
# want|don't
# i|want
# don't|want
# to|want
# i|to
# don't|to
# want|to
# believe|to
# don't|believe
# want|believe
# to|believe
# the|believe
# want|the
# to|the
# believe|the
# world|the
# to|world
# believe|world
# the|world
# is|world
# believe|is
# the|is
# world|is
# so|is
# the|so
# world|so
# is|so
# is|i
# so|i
# want|i
# so|want
# i|want
# a|want
# i|a
# want|a
# want|to
# a|to
# believe|to
# a|believe
# to|believe
# in|believe
# to|in
# believe|in
# i|in
# to|i
# believe|i
# in|i
# want|i
# believe|want
# in|want
# i|want
# anyone|want
# in|anyone
# i|anyone
# want|anyone
# to|anyone
# i|to
# want|to
# anyone|to
# help|to
# want|help
# anyone|help
# to|help
# me|help
# anyone|me
# to|me
# help|me
# help|this
# me|this
# this|i
# cannot|i
# i|cannot
# fucking|cannot
# i|fucking
# cannot|fucking
# deal|fucking
# i|deal
# cannot|deal
# fucking|deal
# with|deal
# cannot|with
# fucking|with
# deal|with
# this|with
# fucking|this
# deal|this
# with|this
# right|this
# deal|right
# with|right
# this|right
# now|right
# with|now
# this|now
# right|now
# it|now
# this|it
# right|it
# now|it
# wasn't|it
# right|wasn't
# now|wasn't
# it|wasn't
# supposed|wasn't
# now|supposed
# it|supposed
# wasn't|supposed
# to|supposed
# it|to
# wasn't|to
# supposed|to
# be|to
# wasn't|be
# supposed|be
# to|be
# like|be
# supposed|like
# to|like
# be|like
# this|like
# to|this
# be|this
# like|this
# i|this
# be|i
# like|i
# this|i
# thought|i
# like|thought
# this|thought
# i|thought
# she|thought
# this|she
# i|she
# thought|she
# said|she
# i|said
# thought|said
# she|said
# at|said
# thought|at
# she|at
# said|at
# this|at
# she|this
# said|this
# at|this
# point|this
# said|point
# at|point
# this|point
# what|point
# at|what
# this|what
# point|what
# does|what
# this|does
# point|does
# what|does
# it|does
# point|it
# what|it
# does|it
# does|this
# it|this
# is|this
# it|is
# this|is
# so|is
# this|so
# is|so
# is|are
# so|are
# all|are
# so|all
# are|all
# are|and
# all|and
# i|and
# all|i
# and|i
# love|i
# and|love
# i|love
# you|love
# and|you
# i|you
# love|you
# for|you
# i|for
# love|for
# you|for
# so|for
# love|so
# you|so
# for|so
# many|so
# you|many
# for|many
# so|many
# reasons|many
# for|reasons
# so|reasons
# many|reasons
# not|reasons
# so|not
# many|not
# reasons|not
# least|not
# many|least
# reasons|least
# not|least
# of|least
# reasons|of
# not|of
# least|of
# which|of
# not|which
# least|which
# of|which
# is|which
# least|is
# of|is
# which|is
# your|is
# of|your
# which|your
# is|your
# crazy|your
# which|crazy
# is|crazy
# your|crazy
# talk|crazy
# is|talk
# your|talk
# crazy|talk
# crazy|to
# talk|to
# maga|to
# talk|maga
# to|maga
# by|maga
# to|by
# maga|by
# your|by
# to|your
# maga|your
# by|your
# by|don’t
# your|don’t
# give|don’t
# your|give
# don’t|give
# a|give
# don’t|a
# give|a
# fuck|a
# don’t|fuck
# give|fuck
# a|fuck
# who|fuck
# give|who
# a|who
# fuck|who
# you|who
# a|you
# fuck|you
# who|you
# are|you
# fuck|are
# who|are
# you|are
# or|are
# who|or
# you|or
# are|or
# where|or
# you|where
# are|where
# or|where
# you|where
# are|you
# or|you
# where|you
# live|you
# or|live
# where|live
# you|live
# you|live
# where|you
# you|you
# live|you
# can|you
# you|can
# live|can
# you|can
# you|on
# can|on
# me|on
# can|me
# on|me
# to|me
# on|to
# me|to
# be|to
# on|be
# me|be
# to|be
# there|be
# me|there
# to|there
# be|there
# to|there
# to|to
# be|to
# there|to
# bring|to
# be|bring
# there|bring
# to|bring
# your|bring
# there|your
# to|your
# bring|your
# fucking|your
# to|fucking
# bring|fucking
# your|fucking
# life|fucking
# bring|life
# your|life
# fucking|life
# to|life
# your|to
# fucking|to
# life|to
# a|to
# fucking|a
# life|a
# to|a
# to|end
# a|end
# end|put
# you|put
# end|you
# put|you
# in|you
# put|in
# you|in
# so|in
# put|so
# you|so
# in|so
# much|so
# you|much
# in|much
# so|much
# fucking|much
# in|fucking
# so|fucking
# much|fucking
# much|that
# fucking|that
# that|make
# make|being
# being|to
# a|to
# being|a
# to|a
# to|in
# a|in
# the|in
# a|the
# in|the
# in|look
# the|look
# like|look
# the|like
# look|like
# a|like
# look|a
# like|a
# fucking|a
# look|fucking
# like|fucking
# a|fucking
# back|fucking
# like|back
# a|back
# fucking|back
# fucking|on
# back|on
# a|on
# back|a
# on|a
# a|i
# don’t|i
# i|don’t
# give|don’t
# i|give
# don’t|give
# a|give
# i|a
# don’t|a
# give|a
# fuck|a
# don’t|fuck
# give|fuck
# a|fuck
# how|fuck
# give|how
# a|how
# fuck|how
# many|how
# a|many
# fuck|many
# how|many
# how|you
# many|you
# have|you
# many|have
# you|have
# or|have
# you|or
# have|or
# how|or
# you|how
# have|how
# or|how
# or|you
# how|you
# are|you
# how|are
# you|are
# you|how
# are|how
# well|how
# are|well
# how|well
# you|well
# how|you
# well|you
# can|you
# how|can
# well|can
# you|can
# fight|can
# well|fight
# you|fight
# can|fight
# or|fight
# you|or
# can|or
# fight|or
# how|or
# can|how
# fight|how
# or|how
# many|how
# fight|many
# or|many
# how|many
# fucking|many
# or|fucking
# how|fucking
# many|fucking
# guns|fucking
# how|guns
# many|guns
# fucking|guns
# you|guns
# many|you
# fucking|you
# guns|you
# own|you
# fucking|own
# guns|own
# you|own
# to|own
# guns|to
# you|to
# own|to
# own|yourself
# to|yourself
# yourself|fucking
# show|fucking
# yourself|show
# fucking|show
# up|show
# fucking|up
# show|up
# at|up
# fucking|at
# show|at
# up|at
# your|at
# show|your
# up|your
# at|your
# house|your
# up|house
# at|house
# your|house
# when|house
# at|when
# your|when
# house|when
# you|when
# your|you
# house|you
# when|you
# when|home
# you|home
# home|all
# the|all
# all|the
# all|on
# the|on
# in|on
# the|in
# on|in
# your|in
# on|your
# in|your
# house|your
# on|house
# in|house
# your|house
# leave|house
# in|leave
# your|leave
# house|leave
# all|leave
# your|all
# house|all
# leave|all
# the|all
# house|the
# leave|the
# all|the
# the|open
# your|open
# open|your
# open|door
# your|door
# and|door
# your|and
# door|and
# not|and
# door|not
# and|not
# and|it
# not|it
# and|it
# not|and
# it|and
# it|your
# and|your
# and|on
# on|and
# let|and
# on|let
# and|let
# them|let
# on|them
# and|them
# let|them
# them|you’re
# going|you’re
# you’re|going
# to|going
# you’re|to
# going|to
# start|to
# you’re|start
# going|start
# to|start
# to|the
# start|the
# fuck|the
# start|fuck
# the|fuck
# out|fuck
# the|out
# fuck|out
# your|out
# the|your
# fuck|your
# out|your
# blood|your
# fuck|blood
# out|blood
# your|blood
# your|will
# blood|will
# will|and
# and|have
# a|have
# and|a
# have|a
# fucking|a
# have|fucking
# a|fucking
# to|go
# go|to
# the|to
# go|the
# to|the
# to|for
# the|for
# a|for
# the|a
# for|a
# a|and
# the|and
# and|the
# last|the
# and|last
# the|last
# thing|last
# and|thing
# the|thing
# last|thing
# last|see
# thing|see
# when|see
# thing|when
# see|when
# you’re|when
# see|you’re
# when|you’re
# being|you’re
# see|being
# when|being
# you’re|being
# put|being
# when|put
# you’re|put
# being|put
# under|put
# you’re|under
# being|under
# put|under
# in|under
# being|in
# put|in
# under|in
# the|in
# put|the
# under|the
# in|the
# the|is
# me|is
# is|me
# me|you
# you|like
# a|like
# you|a
# like|a
# like|when
# a|when
# you|when
# a|you
# when|you
# when|up
# you|up
# after|up
# you|after
# up|after
# being|after
# up|being
# after|being
# after|on
# being|on
# on|what
# what|time
# time|is
# in|is
# time|in
# is|in
# your|in
# is|your
# in|your
# your|to
# go|to
# to|go
# off|go
# to|off
# go|off
# your|from
# from|your
# your|and
# when|and
# and|when
# you|when
# and|you
# when|you
# when|out
# you|out
# the|out
# you|the
# out|the
# front|the
# out|front
# the|front
# door|front
# out|door
# the|door
# front|door
# of|door
# the|of
# front|of
# door|of
# the|of
# front|the
# door|the
# of|the
# of|to
# the|to
# go|to
# the|go
# to|go
# home|go
# to|home
# go|home
# go|run
# home|run
# you|run
# home|you
# run|you
# over|you
# run|over
# you|over
# with|over
# run|with
# you|with
# over|with
# my|with
# you|my
# over|my
# with|my
# fucking|my
# over|fucking
# with|fucking
# my|fucking
# my|out
# fucking|out
# of|out
# fucking|of
# out|of
# no|of
# out|no
# of|no
# where|no
# out|where
# of|where
# no|where
# and|where
# of|and
# no|and
# where|and
# kill|and
# no|kill
# where|kill
# and|kill
# you|kill
# where|you
# and|you
# kill|you
# i|you
# and|i
# kill|i
# you|i
# just|i
# kill|just
# you|just
# i|just
# want|just
# you|want
# i|want
# just|want
# you|want
# i|you
# just|you
# want|you
# to|you
# just|to
# want|to
# you|to
# know|to
# want|know
# you|know
# to|know
# how|know
# you|how
# to|how
# know|how
# know|i
# how|i
# could|i
# how|could
# i|could
# fucking|could
# i|fucking
# could|fucking
# could|your
# fucking|your
# your|of
# a|of
# of|a
# life|a
# of|life
# a|life
# but|life
# of|but
# a|but
# life|but
# how|but
# a|how
# life|how
# but|how
# how|go
# to|go
# go|to
# a|to
# go|a
# to|a
# great|a
# go|great
# to|great
# a|great
# great|to
# make|to
# to|make
# sure|make
# to|sure
# make|sure
# your|sure
# to|your
# make|your
# sure|your
# last|your
# make|last
# sure|last
# your|last
# your|days
# last|days
# are|days
# last|are
# days|are
# days|in
# are|in
# a|in
# are|a
# in|a
# a|fucking
# hell|fucking
# fucking|hell
# it’s|hell
# fucking|it’s
# hell|it’s
# too|it’s
# fucking|too
# hell|too
# it’s|too
# it’s|to
# too|to
# to|yourself
# but|yourself
# to|but
# yourself|but
# don’t|but
# yourself|don’t
# but|don’t
# fucking|you
# and|you
# fucking|and
# you|and
# kill|and
# you|kill
# and|kill
# you|kill
# you|you
# and|you
# kill|you
# again|you
# and|again
# kill|again
# you|again
# myself|again
# kill|myself
# you|myself
# again|myself
# you|myself
# you|you
# again|you
# myself|you
# hell|to
# to|hell
# a|like
# like|a
# a|in
# the|in
# in|the
# in|of
# the|of
# of|ones
# i|ones
# of|i
# ones|i
# made|i
# ones|made
# i|made
# made|to
# it|to
# to|it
# to|it
# to|to
# it|to
# it|the
# to|the
# shit|of
# of|shit
# why|shit
# of|why
# shit|why
# did|why
# of|did
# shit|did
# why|did
# you|did
# shit|you
# why|you
# did|you
# have|you
# why|have
# did|have
# you|have
# to|have
# did|to
# you|to
# have|to
# have|me
# to|me
# of|me
# to|of
# me|of
# this|of
# me|this
# of|this
# god|this
# me|god
# of|god
# this|god
# god|i
# hate|i
# i|hate
# you|hate
# i|you
# hate|you
# and|you
# i|and
# hate|and
# you|and
# you|you
# and|you
# get|you
# and|get
# you|get
# you|was
# get|was
# nearly|was
# get|nearly
# was|nearly
# 10|nearly
# was|10
# nearly|10
# years|10
# was|years
# nearly|years
# 10|years
# ago|years
# nearly|ago
# 10|ago
# years|ago
# years|is
# ago|is
# legal|is
# ago|legal
# is|legal
# age|legal
# is|age
# legal|age
# now|age
# is|now
# legal|now
# age|now
# just|now
# legal|just
# age|just
# now|just
# think|just
# age|think
# now|think
# just|think
# about|think
# now|about
# just|about
# think|about
# that|about
# just|that
# think|that
# about|that
# for|that
# think|for
# about|for
# that|for
# a|for
# about|a
# that|a
# for|a
# while|a
# that|while
# for|while
# a|while
# does|while
# for|does
# a|does
# while|does
# that|does
# a|that
# while|that
# does|that
# make|that
# while|make
# does|make
# that|make
# you|make
# does|you
# that|you
# make|you
# feel|you
# that|feel
# make|feel
# you|feel
# better|feel
# make|better
# you|better
# feel|better
# feel|you
# better|you
# remember|you
# better|remember
# you|remember
# remember|no
# i|no
# no|i
# do|i
# no|do
# i|do
# you|do
# no|you
# i|you
# do|you
# probably|you
# i|probably
# do|probably
# you|probably
# don't|probably
# do|don't
# you|don't
# probably|don't
# remember|don't
# you|remember
# probably|remember
# don't|remember
# remember|crazy
# or|either
# i|either
# either|i
# remember|i
# either|remember
# i|remember
# all|remember
# either|all
# i|all
# remember|all
# of|all
# i|of
# remember|of
# all|of
# them|of
# remember|them
# all|them
# of|them
# in|them
# all|in
# of|in
# them|in
# fact|in
# of|fact
# them|fact
# in|fact
# you|fact
# them|you
# in|you
# fact|you
# have|you
# in|have
# fact|have
# you|have
# only|have
# fact|only
# you|only
# have|only
# have|two
# only|two
# two|to
# to|a
# a|of
# just|of
# a|just
# of|just
# just|and
# have|and
# and|have
# not|have
# and|not
# have|not
# have|there
# not|there
# any|there
# not|any
# there|any
# time|any
# there|time
# any|time
# any|so
# time|so
# so|respect
# my|respect
# so|my
# respect|my
# my|the
# the|of
# the|of
# the|the
# of|the
# of|and
# the|and
# the|and
# the|the
# and|the
# and|of
# the|of
# of|i
# have|i
# of|have
# i|have
# have|to
# my|to
# to|my
# to|for
# my|for
# nearly|for
# my|nearly
# for|nearly
# for|years
# nearly|years
# but|years
# nearly|but
# years|but
# you|but
# years|you
# but|you
# have|you
# years|have
# but|have
# you|have
# no|have
# but|no
# you|no
# have|no
# no|for
# let|for
# for|let
# me|let
# for|me
# let|me
# let|into
# me|into
# your|into
# me|your
# into|your
# mind|your
# into|mind
# your|mind
# and|mind
# into|and
# your|and
# mind|and
# mind|out
# and|out
# a|out
# and|a
# out|a
# out|of
# a|of
# why|of
# a|why
# of|why
# this|why
# of|this
# why|this
# why|you
# this|you
# could|you
# this|could
# you|could
# it|could
# you|it
# could|it
# be|it
# you|be
# could|be
# it|be
# that|be
# could|that
# it|that
# be|that
# be|so
# that|so
# much|so
# that|much
# so|much
# on|much
# so|on
# much|on
# people|on
# so|people
# much|people
# on|people
# who|people
# much|who
# on|who
# people|who
# people|for
# who|for
# your|for
# who|your
# for|your
# country|your
# for|country
# your|country
# can|country
# for|can
# your|can
# country|can
# have|can
# your|have
# country|have
# can|have
# the|have
# country|the
# can|the
# have|the
# the|that
# it|that
# that|it
# that|the
# it|the
# dead|the
# it|dead
# the|dead
# the|you
# dead|you
# may|you
# dead|may
# you|may
# know|may
# you|know
# may|know
# or|know
# you|or
# may|or
# know|or
# be|or
# may|be
# know|be
# or|be
# or|to
# be|to
# or|to
# be|or
# to|or
# might|or
# to|might
# or|might
# be|might
# to|be
# or|be
# might|be
# might|to
# be|to
# you|to
# be|you
# to|you
# in|you
# to|in
# you|in
# some|in
# to|some
# you|some
# in|some
# way|some
# you|way
# in|way
# some|way
# on|way
# in|on
# some|on
# way|on
# our|on
# some|our
# way|our
# on|our
# side|our
# way|side
# on|side
# our|side
# and|side
# on|and
# our|and
# side|and
# the|and
# our|the
# side|the
# and|the
# and|their
# the|their
# side|their
# the|side
# their|side
# and|side
# their|and
# side|and
# makes|and
# their|makes
# side|makes
# and|makes
# it|makes
# side|it
# and|it
# makes|it
# really|it
# and|really
# makes|really
# it|really
# easy|really
# makes|easy
# it|easy
# really|easy
# to|easy
# it|to
# really|to
# easy|to
# easy|people
# to|people
# to|people
# to|to
# people|to
# people|war
# to|war
# around|war
# to|around
# war|around
# the|around
# war|the
# around|the
# world|the
# war|world
# around|world
# the|world
# could|world
# around|could
# the|could
# world|could
# it|could
# the|it
# world|it
# could|it
# be|it
# world|be
# could|be
# it|be
# because|be
# could|because
# it|because
# be|because
# people|because
# it|people
# be|people
# because|people
# people|to
# to|on
# the|on
# to|the
# on|the
# on|who
# the|who
# are|who
# the|are
# who|are
# still|are
# who|still
# are|still
# are|and
# still|and
# and|from
# from|or
# drug|or
# from|drug
# or|drug
# or|or
# drug|or
# are|or
# drug|are
# or|are
# or|or
# are|or
# or|or
# can't|or
# or|can't
# or|can't
# even|can't
# or|even
# can't|even
# can't|like
# even|like
# like|of
# society|of
# of|society
# of|because
# society|because
# they|because
# society|they
# because|they
# were|they
# because|were
# they|were
# they|as
# were|as
# as|for
# some|for
# for|some
# for|political
# some|political
# political|who
# often|who
# political|often
# who|often
# couldn't|often
# who|couldn't
# often|couldn't
# care|couldn't
# who|care
# often|care
# couldn't|care
# less|care
# often|less
# couldn't|less
# care|less
# what|less
# couldn't|what
# care|what
# less|what
# happens|what
# care|happens
# less|happens
# what|happens
# to|happens
# less|to
# what|to
# happens|to
# them|to
# what|them
# happens|them
# to|them
# as|them
# happens|as
# to|as
# them|as
# long|as
# to|long
# them|long
# as|long
# as|long
# them|as
# as|as
# long|as
# they|as
# as|they
# long|they
# as|they
# get|they
# long|get
# as|get
# they|get
# to|get
# as|to
# they|to
# get|to
# to|out
# of|out
# out|of
# a|of
# out|a
# of|a
# a|don't
# get|don't
# don't|get
# me|get
# don't|me
# get|me
# wrong|me
# don't|wrong
# get|wrong
# me|wrong
# there|wrong
# get|there
# me|there
# wrong|there
# is|there
# me|is
# wrong|is
# there|is
# some|is
# wrong|some
# there|some
# is|some
# some|in
# looking|in
# in|looking
# back|looking
# in|back
# looking|back
# at|back
# in|at
# looking|at
# back|at
# the|at
# looking|the
# back|the
# at|the
# at|who
# the|who
# have|who
# the|have
# who|have
# who|and
# have|and
# and|on
# it|on
# and|it
# on|it
# but|it
# on|but
# it|but
# a|but
# on|a
# it|a
# but|a
# a|to
# have|to
# to|have
# a|have
# to|a
# have|a
# whole|a
# to|whole
# have|whole
# a|whole
# day|whole
# have|day
# a|day
# whole|day
# for|day
# a|for
# whole|for
# day|for
# that|for
# whole|that
# day|that
# for|that
# every|that
# day|every
# for|every
# that|every
# year|every
# for|year
# that|year
# every|year
# and|year
# that|and
# every|and
# year|and
# year|why
# and|why
# do|why
# and|do
# why|do
# i|do
# why|i
# do|i
# have|i
# why|have
# do|have
# i|have
# the|have
# do|the
# i|the
# have|the
# the|this
# person|this
# this|person
# wants|person
# this|wants
# person|wants
# to|wants
# this|to
# person|to
# wants|to
# wants|those
# to|those
# dead|those
# to|dead
# those|dead
# dead|in
# war|in
# in|war
# is|war
# in|is
# war|is
# a|is
# in|a
# war|a
# is|a
# stupid|a
# war|stupid
# is|stupid
# a|stupid
# idea|stupid
# is|idea
# a|idea
# stupid|idea
# no|idea
# a|no
# stupid|no
# idea|no
# matter|no
# stupid|matter
# idea|matter
# no|matter
# what|matter
# idea|what
# no|what
# matter|what
# you're|what
# no|you're
# matter|you're
# what|you're
# what|for
# you're|for
# it|for
# you're|it
# for|it
# is|it
# for|is
# it|is
# not|is
# for|not
# it|not
# is|not
# is|to
# not|to
# to|so
# their|so
# so|their
# their|out
# and|out
# out|and
# then|and
# out|then
# and|then
# and|them
# then|them
# in|them
# then|in
# them|in
# the|in
# them|the
# in|the
# in|to
# the|to
# get|to
# the|get
# to|get
# the|get
# to|the
# get|the
# job|the
# to|job
# get|job
# the|job
# done|job
# get|done
# the|done
# job|done
# it|done
# the|it
# job|it
# done|it
# is|it
# job|is
# done|is
# it|is
# not|is
# done|not
# it|not
# is|not
# is|to
# not|to
# to|a
# a|up
# up|people
# with|people
# up|with
# people|with
# people|it
# with|it
# is|it
# with|is
# it|is
# not|is
# it|not
# is|not
# is|to
# not|to
# be|to
# not|be
# to|be
# to|to
# be|to
# to|and
# shit|and
# to|shit
# and|shit
# in|shit
# and|in
# shit|in
# a|in
# and|a
# shit|a
# in|a
# in|while
# a|while
# hell|while
# a|hell
# while|hell
# on|hell
# while|on
# hell|on
# on|all
# all|you
# because|you
# all|because
# you|because
# the|because
# you|the
# because|the
# political|the
# you|political
# because|political
# the|political
# the|that
# political|that
# be|that
# political|be
# that|be
# couldn't|be
# that|couldn't
# be|couldn't
# get|couldn't
# that|get
# be|get
# couldn't|get
# couldn't|at
# get|at
# the|at
# get|the
# at|the
# fucking|the
# at|fucking
# the|fucking
# fucking|the
# reason|the
# the|reason
# it|reason
# the|it
# reason|it
# is|it
# the|is
# reason|is
# it|is
# sad|is
# reason|sad
# it|sad
# is|sad
# and|sad
# it|and
# is|and
# sad|and
# sad|and
# and|and
# and|is
# not|is
# and|not
# is|not
# for|not
# is|for
# not|for
# not|but
# for|but
# for|but
# for|for
# but|for
# the|for
# but|the
# for|the
# for|and
# the|and
# and|that
# that|in
# such|in
# that|such
# in|such
# such|for
# such|for
# for|such
# for|reasons
# such|reasons
# is|reasons
# such|is
# reasons|is
# something|is
# reasons|something
# is|something
# that|something
# reasons|that
# is|that
# something|that
# still|that
# is|still
# something|still
# that|still
# that|to
# still|to
# happen|to
# still|happen
# to|happen
# to|it's
# happen|it's
# because|it's
# happen|because
# it's|because
# if|because
# it's|if
# because|if
# the|if
# it's|the
# because|the
# if|the
# kind|the
# because|kind
# if|kind
# the|kind
# of|kind
# if|of
# the|of
# kind|of
# kind|this
# of|this
# this|is
# being|is
# this|being
# is|being
# is|in
# being|in
# one|in
# being|one
# in|one
# day|one
# in|day
# one|day
# when|day
# in|when
# one|when
# day|when
# he's|when
# one|he's
# day|he's
# when|he's
# when|he
# he's|he
# might|he
# he's|might
# he|might
# be|might
# he|be
# might|be
# might|into
# be|into
# into|either
# the|either
# into|the
# either|the
# either|of
# the|of
# of|who
# are|who
# of|are
# who|are
# who|for
# are|for
# for|in
# in|and
# and|or
# the|or
# and|the
# or|the
# or|of
# the|of
# of|who
# are|who
# of|are
# who|are
# often|are
# who|often
# are|often
# completely|often
# who|completely
# are|completely
# often|completely
# shit|completely
# are|shit
# often|shit
# completely|shit
# completely|by
# shit|by
# their|by
# shit|their
# by|their
# by|for
# their|for
# some|for
# their|some
# for|some
# bullshit|some
# for|bullshit
# some|bullshit
# war|bullshit
# for|war
# some|war
# bullshit|war
# that|war
# some|that
# bullshit|that
# war|that
# probably|that
# bullshit|probably
# war|probably
# that|probably
# didn't|probably
# war|didn't
# that|didn't
# probably|didn't
# need|didn't
# that|need
# probably|need
# didn't|need
# to|need
# probably|to
# didn't|to
# need|to
# be|to
# didn't|be
# need|be
# to|be
# are|you
# you|are
# literally|are
# you|literally
# are|literally
# so|literally
# you|so
# are|so
# literally|so
# out|so
# are|out
# literally|out
# so|out
# of|out
# literally|of
# so|of
# out|of
# line|of
# so|line
# out|line
# of|line
# it’s|line
# out|it’s
# of|it’s
# line|it’s
# fucking|it’s
# of|fucking
# line|fucking
# it’s|fucking
# it’s|i
# fucking|i
# could|i
# fucking|could
# i|could
# i|you
# could|you
# so|you
# could|so
# you|so
# hard|so
# you|hard
# so|hard
# right|hard
# you|right
# so|right
# hard|right
# now|right
# so|now
# hard|now
# right|now
# but|now
# hard|but
# right|but
# now|but
# i|but
# right|i
# now|i
# but|i
# know|i
# now|know
# but|know
# i|know
# i|just
# know|just
# end|just
# know|end
# just|end
# up|end
# just|up
# end|up
# end|i’ve
# up|i’ve
# i’ve|you
# before|you
# i’ve|before
# you|before
# and|before
# you|and
# before|and
# you|and
# you|you
# before|you
# and|you
# know|you
# before|know
# and|know
# you|know
# it|know
# and|it
# you|it
# know|it
# know|are
# it|are
# are|just
# say|just
# are|say
# just|say
# i|say
# just|i
# say|i
# say|you
# i|you
# because|you
# i|because
# you|because
# you’re|because
# you|you’re
# because|you’re
# gay|you’re
# you|gay
# because|gay
# you’re|gay
# and|gay
# because|and
# you’re|and
# gay|and
# have|and
# you’re|have
# gay|have
# and|have
# different|have
# gay|different
# and|different
# have|different
# have|talk
# different|talk
# shit|talk
# different|shit
# talk|shit
# get|shit
# talk|get
# shit|get
# hit|get
# talk|hit
# shit|hit
# get|hit
# you|hit
# shit|you
# get|you
# hit|you
# don’t|you
# get|don’t
# hit|don’t
# you|don’t
# don’t|with
# me|with
# with|me
# with|i’ve
# me|i’ve
# got|i’ve
# me|got
# i’ve|got
# a|got
# i’ve|a
# got|a
# black|a
# i’ve|black
# got|black
# a|black
# a|i
# black|i
# know|i
# black|know
# i|know
# i|are
# know|are
# are|up
# but|up
# are|but
# up|but
# that’s|but
# up|that’s
# but|that’s
# all|that’s
# up|all
# but|all
# that’s|all
# i’ve|all
# but|i’ve
# that’s|i’ve
# all|i’ve
# been|i’ve
# that’s|been
# all|been
# i’ve|been
# i’ve|all
# been|all
# day|all
# been|day
# all|day
# probably|day
# all|probably
# day|probably
# from|probably
# all|from
# day|from
# probably|from
# her|from
# day|her
# probably|her
# from|her
# all|and
# and|all
# of|all
# and|of
# all|of
# her|of
# and|her
# all|her
# of|her
# of|friends
# her|friends
# but|friends
# her|but
# friends|but
# you|but
# friends|you
# but|you
# can|you
# friends|can
# but|can
# you|can
# you|up
# can|up
# on|up
# can|on
# up|on
# me|on
# up|me
# on|me
# and|me
# up|and
# on|and
# me|and
# make|and
# on|make
# me|make
# and|make
# and|of
# make|of
# me|of
# make|me
# of|me
# for|me
# of|for
# me|for
# being|for
# of|being
# me|being
# for|being
# for|all
# being|all
# you|all
# being|you
# all|you
# want|you
# all|want
# you|want
# i’ve|want
# all|i’ve
# you|i’ve
# want|i’ve
# been|i’ve
# you|been
# want|been
# i’ve|been
# i’ve|a
# been|a
# lot|a
# been|lot
# a|lot
# my|lot
# a|my
# lot|my
# first|my
# a|first
# lot|first
# my|first
# first|on
# me|on
# on|me
# my|me
# on|my
# me|my
# my|if
# i|if
# if|i
# forget|i
# if|forget
# i|forget
# to|forget
# if|to
# i|to
# forget|to
# do|to
# i|do
# forget|do
# to|do
# my|do
# forget|my
# to|my
# do|my
# do|and
# my|and
# there|and
# my|there
# and|there
# are|there
# and|are
# there|are
# some|are
# and|some
# there|some
# are|some
# days|some
# there|days
# are|days
# some|days
# i|days
# are|i
# some|i
# days|i
# don’t|i
# some|don’t
# days|don’t
# i|don’t
# even|don’t
# days|even
# i|even
# don’t|even
# want|even
# i|want
# don’t|want
# even|want
# to|want
# don’t|to
# even|to
# want|to
# get|to
# even|get
# want|get
# to|get
# out|get
# want|out
# to|out
# get|out
# of|out
# to|of
# get|of
# out|of
# out|in
# of|in
# the|in
# of|the
# in|the
# in|i’m
# the|i’m
# a|i’m
# the|a
# i’m|a
# been|i’ve
# i’ve|been
# through|been
# i’ve|through
# been|through
# shit|through
# i’ve|shit
# been|shit
# through|shit
# that|shit
# been|that
# through|that
# shit|that
# you|that
# through|you
# shit|you
# that|you
# that|even
# you|even
# even|of
# you|of
# even|you
# of|you
# think|you
# of|think
# you|think
# your|think
# of|your
# you|your
# think|your
# life|your
# you|life
# think|life
# your|life
# is|life
# think|is
# your|is
# life|is
# hard|is
# your|hard
# life|hard
# is|hard
# try|hard
# life|try
# is|try
# hard|try
# hard|the
# try|the
# the|guy
# in|guy
# the|in
# guy|in
# your|in
# guy|your
# in|your
# in|out
# your|out
# in|out
# your|in
# out|in
# the|in
# out|the
# in|the
# in|of
# the|of
# the|of
# the|the
# of|the
# of|only
# the|only
# to|only
# the|to
# only|to
# find|to
# only|find
# to|find
# out|find
# only|out
# to|out
# find|out
# he|out
# to|he
# find|he
# out|he
# has|he
# find|has
# out|has
# he|has
# a|has
# out|a
# he|a
# has|a
# fucking|a
# he|fucking
# has|fucking
# a|fucking
# a|you
# fucking|you
# don’t|you
# fucking|don’t
# you|don’t
# know|don’t
# you|know
# don’t|know
# my|know
# you|my
# don’t|my
# know|my
# life|my
# don’t|life
# know|life
# my|life
# or|life
# know|or
# my|or
# life|or
# my|or
# my|my
# life|my
# or|my
# or|so
# my|so
# keep|so
# my|keep
# so|keep
# my|keep
# so|my
# keep|my
# name|my
# so|name
# keep|name
# my|name
# out|name
# keep|out
# my|out
# name|out
# of|out
# my|of
# name|of
# out|of
# your|of
# name|your
# out|your
# of|your
# your|life
# is|life
# life|is
# a|is
# life|a
# is|a
# is|and
# a|and
# it|and
# a|it
# and|it
# looks|it
# and|looks
# it|looks
# like|looks
# and|like
# it|like
# looks|like
# i’ve|like
# it|i’ve
# looks|i’ve
# like|i’ve
# already|i’ve
# looks|already
# like|already
# i’ve|already
# i’ve|are
# already|are
# all|are
# already|all
# are|all
# are|and
# all|and
# i|and
# all|i
# and|i
# love|i
# and|love
# i|love
# you|love
# and|you
# i|you
# love|you
# for|you
# i|for
# love|for
# you|for
# so|for
# love|so
# you|so
# for|so
# many|so
# you|many
# for|many
# so|many
# reasons|many
# for|reasons
# so|reasons
# many|reasons
# not|reasons
# so|not
# many|not
# reasons|not
# least|not
# many|least
# reasons|least
# not|least
# of|least
# reasons|of
# not|of
# least|of
# which|of
# not|which
# least|which
# of|which
# is|which
# least|is
# of|is
# which|is
# your|is
# of|your
# which|your
# is|your
# crazy|your
# which|crazy
# is|crazy
# your|crazy
# talk|crazy
# is|talk
# your|talk
# crazy|talk
# crazy|to
# talk|to
# maga|to
# talk|maga
# to|maga
# by|maga
# to|by
# maga|by
# your|by
# to|your
# maga|your
# by|your
# by|are
# your|are
# all|are
# your|all
# are|all
# are|and
# all|and
# i|and
# all|i
# and|i
# love|i
# and|love
# i|love
# you|love
# and|you
# i|you
# love|you
# for|you
# i|for
# love|for
# you|for
# so|for
# love|so
# you|so
# for|so
# many|so
# you|many
# for|many
# so|many
# reasons|many
# for|reasons
# so|reasons
# many|reasons
# not|reasons
# so|not
# many|not
# reasons|not
# least|not
# many|least
# reasons|least
# not|least
# of|least
# reasons|of
# not|of
# least|of
# which|of
# not|which
# least|which
# of|which
# is|which
# least|is
# of|is
# which|is
# your|is
# of|your
# which|your
# is|your
# crazy|your
# which|crazy
# is|crazy
# your|crazy
# talk|crazy
# is|talk
# your|talk
# crazy|talk
# crazy|to
# talk|to
# maga|to
# talk|maga
# to|maga
# by|maga
# to|by
# maga|by
# your|by
# to|your
# maga|your
# by|your
# by|forget
# your|forget
# the|forget
# your|the
# forget|the
# the|that
# show|that
# that|show
# up|show
# that|up
# show|up
# up|getting
# real|getting
# getting|real
# when|real
# getting|when
# real|when
# that|when
# getting|that
# real|that
# when|that
# happens|that
# real|happens
# when|happens
# that|happens
# that|being
# happens|being
# a|being
# happens|a
# being|a
# a|is
# far|is
# is|far
# from|far
# is|from
# far|from
# far|i
# from|i
# i|most
# of|most
# i|of
# most|of
# my|of
# most|my
# of|my
# of|in
# my|in
# a|in
# my|a
# in|a
# in|that
# a|that
# that|of
# of|either
# either|or
# or|my
# my|off
# because|off
# my|because
# off|because
# i|because
# off|i
# because|i
# don't|i
# off|don't
# because|don't
# i|don't
# make|don't
# because|make
# i|make
# don't|make
# enough|make
# i|enough
# don't|enough
# make|enough
# to|enough
# don't|to
# make|to
# enough|to
# keep|to
# make|keep
# enough|keep
# to|keep
# the|keep
# enough|the
# to|the
# keep|the
# the|it's
# not|it's
# it's|not
# it's|either
# not|either
# i've|either
# not|i've
# either|i've
# never|i've
# either|never
# i've|never
# i've|anyone
# never|anyone
# down|anyone
# never|down
# anyone|down
# back|down
# anyone|back
# down|back
# down|or
# back|or
# been|or
# back|been
# or|been
# in|been
# or|in
# been|in
# a|in
# or|a
# been|a
# in|a
# a|there
# was|there
# there|was
# one|was
# there|one
# was|one
# one|that
# still|that
# that|still
# that|me
# still|me
# to|me
# still|to
# me|to
# this|to
# me|this
# to|this
# to|was
# this|was
# almost|was
# this|almost
# was|almost
# almost|on
# the|on
# on|the
# on|before
# the|before
# before|i
# should|i
# i|should
# have|should
# i|have
# should|have
# left|have
# i|left
# should|left
# have|left
# already|left
# should|already
# have|already
# left|already
# i|already
# have|i
# left|i
# already|i
# had|i
# left|had
# already|had
# i|had
# an|had
# already|an
# i|an
# had|an
# me|for
# for|me
# with|me
# for|with
# me|with
# a|with
# for|a
# me|a
# with|a
# with|of
# a|of
# of|but
# i|but
# but|i
# was|i
# but|was
# i|was
# taking|was
# but|taking
# i|taking
# was|taking
# the|taking
# i|the
# was|the
# taking|the
# next|the
# was|next
# taking|next
# the|next
# the|off
# next|off
# and|off
# next|and
# off|and
# i|and
# off|i
# and|i
# wanted|i
# off|wanted
# and|wanted
# i|wanted
# to|wanted
# and|to
# i|to
# wanted|to
# get|to
# i|get
# wanted|get
# to|get
# to|up
# get|up
# on|up
# get|on
# up|on
# some|on
# up|some
# on|some
# on|just
# some|just
# as|just
# some|as
# just|as
# i|as
# just|i
# as|i
# was|i
# just|was
# as|was
# i|was
# i|my
# was|my
# my|and
# and|the
# the|on
# my|on
# the|my
# on|my
# my|if
# i|if
# if|i
# if|let
# i|let
# my|let
# i|my
# let|my
# let|leave
# my|leave
# leave|she
# would|she
# leave|would
# she|would
# have|would
# she|have
# would|have
# would|a
# have|a
# a|for
# me|for
# a|me
# for|me
# that|me
# for|that
# me|that
# i|that
# for|i
# me|i
# that|i
# wouldn't|i
# me|wouldn't
# that|wouldn't
# i|wouldn't
# have|wouldn't
# that|have
# i|have
# wouldn't|have
# seen|have
# i|seen
# wouldn't|seen
# have|seen
# it|seen
# wouldn't|it
# have|it
# seen|it
# until|it
# have|until
# seen|until
# it|until
# next|until
# seen|next
# it|next
# until|next
# year|next
# it|year
# until|year
# next|year
# i|year
# until|i
# next|i
# year|i
# year|for
# i|for
# a|for
# i|a
# for|a
# a|for
# my|for
# for|my
# office|my
# for|office
# my|office
# door|office
# for|door
# my|door
# office|door
# when|door
# my|when
# office|when
# door|when
# a|when
# office|a
# door|a
# when|a
# thought|a
# door|thought
# when|thought
# a|thought
# of|thought
# when|of
# a|of
# thought|of
# into|me
# me|into
# me|man
# into|man
# was|man
# into|was
# man|was
# using|was
# man|using
# was|using
# a|using
# man|a
# was|a
# using|a
# a|and
# and|was
# was|he
# called|he
# was|called
# he|called
# wanted|and
# and|wanted
# my|wanted
# and|my
# wanted|my
# help|my
# and|help
# wanted|help
# my|help
# taking|help
# wanted|taking
# my|taking
# help|taking
# down|taking
# my|down
# help|down
# taking|down
# a|down
# help|a
# taking|a
# down|a
# a|i
# was|i
# i|was
# i|but
# was|but
# the|but
# was|the
# but|the
# man|the
# but|man
# the|man
# told|man
# but|told
# the|told
# man|told
# me|told
# the|me
# man|me
# told|me
# there|me
# man|there
# told|there
# me|there
# was|there
# told|was
# me|was
# there|was
# an|was
# me|an
# there|an
# was|an
# me|for
# for|me
# in|me
# for|in
# me|in
# my|in
# for|my
# me|my
# in|my
# in|he
# my|he
# said|he
# my|said
# he|said
# there|said
# he|there
# said|there
# would|there
# he|would
# said|would
# there|would
# be|would
# said|be
# there|be
# would|be
# further|be
# there|further
# would|further
# be|further
# be|and
# further|and
# and|me
# a|me
# and|a
# me|a
# a|something
# didn't|something
# something|didn't
# feel|didn't
# something|feel
# didn't|feel
# right|feel
# something|right
# didn't|right
# feel|right
# but|right
# didn't|but
# feel|but
# right|but
# sure|but
# feel|sure
# right|sure
# but|sure
# enough|sure
# right|enough
# but|enough
# sure|enough
# there|enough
# but|there
# sure|there
# enough|there
# was|there
# sure|was
# enough|was
# there|was
# an|was
# enough|an
# there|an
# was|an
# was|of
# an|of
# of|for
# me|for
# for|me
# it|me
# for|it
# me|it
# was|it
# for|was
# me|was
# it|was
# a|was
# me|a
# it|a
# was|a
# hear|didn't
# didn't|hear
# back|hear
# didn't|back
# hear|back
# from|back
# didn't|from
# hear|from
# back|from
# from|until
# almost|until
# until|almost
# until|i
# almost|i
# was|i
# almost|was
# i|was
# to|was
# i|to
# was|to
# was|a
# to|a
# a|it
# was|it
# a|was
# it|was
# supposed|was
# it|supposed
# was|supposed
# to|supposed
# it|to
# was|to
# supposed|to
# be|to
# was|be
# supposed|be
# to|be
# to|but
# be|but
# as|but
# be|as
# but|as
# an|as
# but|an
# as|an
# as|i
# an|i
# don't|i
# an|don't
# i|don't
# like|don't
# i|like
# don't|like
# being|like
# i|being
# don't|being
# like|being
# like|in
# being|in
# the|in
# being|the
# in|the
# in|i
# the|i
# i|out
# the|out
# i|the
# out|the
# out|point
# the|point
# and|point
# the|and
# point|and
# point|for
# and|for
# for|to
# bring|to
# to|bring
# the|bring
# to|the
# bring|the
# bring|i
# the|i
# was|i
# the|was
# i|was
# able|was
# i|able
# was|able
# to|able
# i|to
# was|to
# able|to
# able|the
# to|the
# the|man
# man|and
# and|him
# i|him
# and|i
# him|i
# him|that
# i|that
# i|that
# i|i
# that|i
# respect|i
# that|respect
# i|respect
# his|respect
# that|his
# i|his
# respect|his
# right|his
# i|right
# respect|right
# his|right
# to|right
# respect|to
# his|to
# right|to
# right|but
# to|but
# that|but
# to|that
# but|that
# we|that
# but|we
# that|we
# had|we
# but|had
# that|had
# we|had
# to|had
# that|to
# we|to
# had|to
# have|to
# we|have
# had|have
# to|have
# a|have
# had|a
# to|a
# have|a
# a|on
# on|to
# my|to
# on|my
# to|my
# to|the
# my|the
# man|the
# my|man
# the|man
# wasn't|man
# the|wasn't
# man|wasn't
# my|wasn't
# the|my
# man|my
# wasn't|my
# wasn't|but
# my|but
# just|but
# my|just
# but|just
# some|just
# but|some
# just|some
# some|who
# who|a
# job|a
# who|job
# a|job
# on|job
# a|on
# job|on
# job|someone
# on|someone
# who|someone
# on|who
# someone|who
# just|who
# someone|just
# who|just
# who|his
# just|his
# his|with
# a|with
# his|a
# with|a
# a|him
# to|him
# him|to
# him|a
# to|a
# a|the
# kid|the
# a|kid
# the|kid
# was|kid
# the|was
# kid|was
# was|out
# and|out
# out|and
# i|and
# out|i
# and|i
# could|i
# out|could
# and|could
# i|could
# tell|could
# and|tell
# i|tell
# could|tell
# he|tell
# i|he
# could|he
# tell|he
# knew|he
# could|knew
# tell|knew
# he|knew
# nothing|knew
# tell|nothing
# he|nothing
# knew|nothing
# so|nothing
# he|so
# knew|so
# nothing|so
# i|so
# knew|i
# nothing|i
# so|i
# so|the
# i|the
# the|and
# let|and
# the|let
# and|let
# him|let
# and|him
# let|him
# using|was
# was|using
# could|nothing
# nothing|could
# be|could
# nothing|be
# could|be
# could|back
# be|back
# to|back
# be|to
# back|to
# him|to
# back|him
# to|him
# very|him
# back|very
# to|very
# him|very
# him|the
# very|the
# the|was
# was|with
# a|with
# was|a
# with|a
# i|so
# so|i
# had|i
# so|had
# i|had
# no|had
# so|no
# i|no
# had|no
# had|but
# no|but
# to|but
# no|to
# but|to
# take|to
# but|take
# to|take
# it|take
# but|it
# to|it
# take|it
# back|it
# to|back
# take|back
# it|back
# to|back
# take|to
# it|to
# back|to
# the|to
# it|the
# back|the
# to|the
# office|the
# back|office
# to|office
# the|office
# and|office
# to|and
# the|and
# office|and
# office|the
# and|the
# the|again
# i|again
# again|i
# wouldn't|i
# again|wouldn't
# i|wouldn't
# be|wouldn't
# again|be
# i|be
# wouldn't|be
# wouldn't|long
# be|long
# i|long
# be|i
# long|i
# long|back
# i|back
# to|back
# i|to
# back|to
# my|to
# back|my
# to|my
# to|and
# my|and
# and|it
# it|i
# i|the
# small|the
# i|small
# the|small
# the|of
# small|of
# of|out
# from|out
# of|from
# out|from
# under|from
# out|under
# from|under
# my|under
# out|my
# from|my
# under|my
# my|and
# read|and
# and|read
# it|read
# and|it
# read|it
# the|of
# my|of
# the|my
# of|my
# office|my
# of|office
# my|office
# i|office
# of|i
# my|i
# office|i
# office|the
# i|the
# the|i
# was|i
# i|was
# going|was
# i|going
# was|going
# to|going
# i|to
# was|to
# going|to
# have|to
# was|have
# going|have
# to|have
# a|have
# going|a
# to|a
# have|a
# a|day
# too|day
# day|too
# because|too
# day|because
# too|because
# the|because
# day|the
# too|the
# because|the
# first|the
# too|first
# because|first
# the|first
# thing|first
# because|thing
# the|thing
# first|thing
# i|thing
# the|i
# first|i
# thing|i
# thing|was
# i|was
# a|was
# i|a
# was|a
# was|of
# a|of
# of|a
# also|was
# a|was
# also|a
# was|a
# a|to
# ...
# what|not
# of|what
# not|what
# i|what
# not|i
# what|i
# what|and
# i|and
# but|one
# one|but
# i|but
# one|i
# but|i
# know|i
# one|know
# but|know
# i|know
# one|know
# but|one
# i|one
# know|one
# when|one
# i|when
# know|when
# one|when
# i|when
# know|i
# one|i
# when|i
# see|i
# one|see
# when|see
# i|see
# you|if
# if|you
# don’t|you
# if|don’t
# you|don’t
# you|guns
# don’t|guns
# how|guns
# don’t|how
# guns|how
# do|how
# guns|do
# how|do
# you|do
# guns|you
# how|you
# do|you
# know|you
# how|know
# do|know
# you|know
# you|high
# know|high
# the|are
# are|the
# most|the
# are|most
# the|most
# the|people
# most|people
# people|them
# because|them
# people|because
# them|because
# they’re|because
# them|they’re
# because|they’re
# the|they’re
# them|the
# because|the
# they’re|the
# most|the
# because|most
# they’re|most
# the|most
# the|asked
# most|asked
# asked|people
# that|people
# asked|that
# people|that
# want|that
# people|want
# that|want
# they|what
# what|they
# think|they
# what|think
# they|think
# if|also
# also|if
# they|if
# also|they
# if|they
# know|they
# also|know
# if|know
# they|know
# the|know
# if|the
# they|the
# know|the
# know|for
# the|for
# for|a
# gun|a
# for|gun
# a|gun
# i|gun
# a|i
# gun|i
# have|i
# a|have
# gun|have
# i|have
# yet|have
# gun|yet
# i|yet
# have|yet
# to|yet
# i|to
# have|to
# yet|to
# get|to
# have|get
# yet|get
# to|get
# an|get
# yet|an
# to|an
# get|an
# get|from
# an|from
# from|most
# likely|most
# from|likely
# most|likely
# part|likely
# most|part
# likely|part
# of|part
# most|of
# likely|of
# part|of
# it|of
# likely|it
# part|it
# of|it
# but|it
# part|but
# of|but
# it|but
# i|but
# of|i
# it|i
# but|i
# also|i
# it|also
# but|also
# i|also
# think|also
# but|think
# i|think
# also|think
# they|think
# i|they
# also|they
# think|they
# have|they
# also|have
# think|have
# they|have
# no|have
# think|no
# they|no
# have|no
# idea|no
# they|idea
# have|idea
# no|idea
# how|idea
# have|how
# no|how
# idea|how
# of|how
# no|of
# idea|of
# how|of
# how|of
# idea|how
# how|how
# of|how
# you|how
# how|you
# of|you
# how|you
# actually|you
# of|actually
# how|actually
# you|actually
# go|actually
# how|go
# you|go
# actually|go
# about|go
# you|about
# actually|about
# go|about
# go|a
# about|a
# gun|a
# about|gun
# a|gun
# or|gun
# a|or
# gun|or
# what|or
# a|what
# gun|what
# or|what
# the|what
# gun|the
# or|the
# what|the
# what|are
# the|are
# for|are
# the|for
# are|for
# for|most
# likely|most
# most|likely
# part|likely
# most|part
# likely|part
# of|part
# most|of
# likely|of
# part|of
# it|of
# likely|it
# part|it
# of|it
# but|it
# part|but
# of|but
# it|but
# i|but
# of|i
# it|i
# but|i
# also|i
# it|also
# but|also
# i|also
# think|also
# but|think
# i|think
# also|think
# they|think
# i|they
# also|they
# think|they
# have|they
# also|have
# think|have
# they|have
# no|have
# think|no
# they|no
# have|no
# idea|no
# they|idea
# have|idea
# no|idea
# how|idea
# have|how
# no|how
# idea|how
# of|how
# no|of
# idea|of
# how|of
# how|of
# idea|how
# how|how
# of|how
# you|how
# how|you
# of|you
# how|you
# actually|you
# of|actually
# how|actually
# you|actually
# go|actually
# how|go
# you|go
# actually|go
# about|go
# you|about
# actually|about
# go|about
# go|a
# about|a
# gun|a
# about|gun
# a|gun
# or|gun
# a|or
# gun|or
# what|or
# a|what
# gun|what
# or|what
# the|what
# gun|the
# or|the
# what|the
# what|are
# the|are
# for|are
# the|for
# are|for
# for|needs
# to|needs
# needs|to
# be|to
# needs|be
# to|be
# be|age
# be|age
# age|be
# age|back
# be|back
# to|back
# be|to
# back|to
# back|no
# to|no
# way|no
# to|way
# no|way
# are|way
# no|are
# way|are
# you|are
# no|you
# way|you
# are|you
# are|enough
# you|enough
# to|enough
# you|to
# enough|to
# vote|to
# enough|vote
# to|vote
# and|vote
# enough|and
# to|and
# vote|and
# not|and
# to|not
# vote|not
# and|not
# and|a
# not|a
# fire|a
# not|fire
# a|fire
# a|not
# fire|not
# exactly|not
# fire|exactly
# not|exactly
# the|exactly
# not|the
# exactly|the
# the|but
# i|but
# but|i
# can't|i
# but|can't
# i|can't
# i|how
# can't|how
# he|how
# can't|he
# how|he
# thought|he
# how|thought
# he|thought
# it|thought
# how|it
# he|it
# thought|it
# would|it
# he|would
# thought|would
# it|would
# be|would
# thought|be
# it|be
# would|be
# a|be
# it|a
# would|a
# be|a
# good|a
# would|good
# be|good
# a|good
# look|good
# be|look
# a|look
# good|look
# it's|look
# a|it's
# good|it's
# look|it's
# it's|of
# the|of
# of|the
# in|move
# move|in
# in|but
# but|in
# like|in
# but|like
# in|like
# a|like
# but|a
# in|a
# like|a
# really|a
# in|really
# like|really
# a|really
# not|really
# like|not
# a|not
# really|not
# really|way
# not|way
# that's|way
# not|that's
# way|that's
# exactly|that's
# way|exactly
# that's|exactly
# what|exactly
# way|what
# that's|what
# exactly|what
# i|what
# that's|i
# exactly|i
# what|i
# what|too
# i|too
# i'm|too
# i|i'm
# too|i'm
# too|his
# i'm|his
# his|out
# a|out
# out|a
# little|a
# out|little
# a|little
# bit|little
# out|bit
# a|bit
# little|bit
# for|bit
# a|for
# little|for
# bit|for
# that|white
# it|what
# what|it
# was|it
# what|was
# it|was
# like|was
# what|like
# it|like
# was|like
# for|like
# it|for
# was|for
# like|for
# for|to
# live|to
# to|live
# in|live
# to|in
# live|in
# in|government
# government|or
# or|the
# the|everything
# everything|the
# news|the
# everything|news
# the|news
# media|news
# everything|media
# the|media
# news|media
# arms|media
# the|arms
# news|arms
# media|arms
# police|arms
# news|police
# media|police
# arms|police
# the|police
# media|the
# arms|the
# police|the
# armed|the
# arms|armed
# police|armed
# the|armed
# the|the
# armed|the
# all|of
# of|from
# from|to
# to|all
# all|and
# and|political
# political|started
# at|started
# political|at
# started|at
# a|at
# started|a
# at|a
# very|a
# started|very
# at|very
# a|very
# a|age
# very|age
# and|age
# very|and
# age|and
# age|by
# and|by
# by|of
# the|of
# by|the
# of|the
# the|with
# the|with
# with|the
# the|of
# of|mind
# control|mind
# of|control
# mind|control
# children|control
# mind|children
# control|children
# were|children
# mind|were
# control|were
# children|were
# children|in
# were|in
# school|in
# were|school
# in|school
# to|school
# in|to
# school|to
# school|even
# to|even
# their|even
# to|their
# even|their
# own|their
# even|own
# their|own
# parents|own
# even|parents
# their|parents
# own|parents
# for|parents
# their|for
# own|for
# parents|for
# for|about
# about|or
# or|actually
# actually|gun
# control|gun
# actually|control
# gun|control
# gun|after
# control|after
# he|after
# control|he
# after|he
# after|to
# he|to
# power|to
# he|power
# to|power
# with|power
# to|with
# power|with
# the|with
# to|the
# power|the
# with|the
# with|of
# the|of
# of|of
# course|of
# of|course
# but|course
# of|but
# course|but
# that’s|but
# of|that’s
# course|that’s
# but|that’s
# a|that’s
# course|a
# but|a
# that’s|a
# different|a
# but|different
# that’s|different
# a|different
# different|nothing
# in|nothing
# nothing|in
# in|that
# makes|that
# that|makes
# it|makes
# that|it
# makes|it
# makes|the
# it|the
# other|the
# it|other
# the|other
# hand|other
# the|hand
# other|hand
# the|hand
# the|the
# other|the
# hand|the
# idea|the
# other|idea
# hand|idea
# the|idea
# of|idea
# hand|of
# the|of
# idea|of
# a|of
# the|a
# idea|a
# of|a
# a|at
# at|everything
# everything|down
# and|down
# everything|and
# down|and
# down|it
# and|it
# with|it
# and|with
# it|with
# an|with
# it|an
# with|an
# an|is
# very|is
# is|very
# much|very
# is|much
# very|much
# a|much
# is|a
# very|a
# much|a
# much|of
# a|of
# of|is
# communism|is
# of|communism
# is|communism
# communism|with
# here|with
# with|here
# with|we
# here|we
# need|we
# here|need
# we|need
# to|need
# we|to
# need|to
# get|to
# we|get
# need|get
# to|get
# on|get
# need|on
# to|on
# get|on
# get|and
# on|and
# be|and
# on|be
# and|be
# and|about
# be|about
# politics|about
# be|politics
# about|politics
# and|politics
# about|and
# politics|and
# and|gun
# gun|for
# people|for
# gun|people
# for|people
# he|people
# for|he
# people|he
# knew|he
# for|knew
# people|knew
# he|knew
# would|knew
# people|would
# he|would
# knew|would
# knew|his
# would|his
# his|and
# and|his
# every|his
# and|every
# his|every
# his|he
# every|he
# he|guns
# away|guns
# he|away
# guns|away
# from|away
# guns|from
# away|from
# the|from
# guns|the
# away|the
# from|the
# the|that
# were|that
# that|were
# a|were
# that|a
# were|a
# were|to
# a|to
# his|to
# a|his
# to|his
# world|his
# to|world
# his|world
# his|the
# world|the
# the|the
# the|etc
# these|etc
# the|these
# etc|these
# people|these
# etc|people
# these|people
# were|people
# etc|were
# these|were
# people|were
# were|to
# the|to
# to|the
# the|they
# were|they
# they|were
# they|first
# were|first
# of|first
# were|of
# first|of
# course|of
# first|course
# of|course
# to|course
# first|to
# of|to
# course|to
# make|to
# of|make
# course|make
# to|make
# their|make
# course|their
# to|their
# make|their
# their|is
# is|there's
# nothing|there's
# is|nothing
# there's|nothing
# good|nothing
# there's|good
# nothing|good
# about|good
# there's|about
# nothing|about
# good|about
# it|about
# nothing|it
# good|it
# about|it
# about|was
# it|was
# it|was
# it|it
# was|it
# about|it
# was|about
# it|about
# the|about
# was|the
# it|the
# about|the
# about|of
# the|of
# of|that
# was|that
# of|was
# that|was
# the|was
# that|the
# was|the
# was|to
# the|to
# make|to
# the|make
# to|make
# it|make
# to|it
# make|it
# sound|it
# to|sound
# make|sound
# it|sound
# good|sound
# make|good
# it|good
# sound|good
# it|good
# it|it
# sound|it
# good|it
# was|it
# sound|was
# good|was
# it|was
# it|evil
# was|evil
# evil|and
# stupid|and
# and|stupid
# it's|stupid
# and|it's
# stupid|it's
# not|it's
# and|not
# stupid|not
# it's|not
# the|not
# stupid|the
# it's|the
# not|the
# not|of
# the|of
# communism|of
# the|communism
# of|communism
# it's|communism
# of|it's
# communism|it's
# communism|another
# it's|another
# another|of
# it|of
# another|it
# of|it
# communism|it
# of|communism
# it|communism
# was|communism
# of|was
# it|was
# communism|was
# is|it
# doesn't|it
# it|doesn't
# matter|doesn't
# it|matter
# doesn't|matter
# the|matter
# it|the
# doesn't|the
# matter|the
# name|the
# doesn't|name
# matter|name
# the|name
# or|name
# matter|or
# the|or
# name|or
# the|or
# the|the
# name|the
# or|the
# or|of
# the|of
# their|of
# the|their
# of|their
# their|of
# of|people
# people|as
# a|as
# people|a
# as|a
# as|of
# a|of
# it|of
# a|it
# of|it
# of|it
# it|it
# and|it
# it|and
# it|and
# move|and
# it|move
# and|move
# and|entire
# move|entire
# entire|is
# is|on
# a|on
# is|a
# on|a
# huge|a
# on|huge
# a|huge
# huge|by
# by|ever
# since|ever
# by|since
# ever|since
# the|since
# ever|the
# since|the
# the|and
# the|and
# and|the
# american|the
# and|american
# the|american
# the|left
# american|left
# had|left
# american|had
# left|had
# to|had
# left|to
# had|to
# to|from
# the|from
# from|the
# from|it
# the|it
# it|read
# the|read
# it|the
# read|the
# big|the
# read|big
# the|big
# the|actually
# big|actually
# actually|gun
# control|gun
# actually|control
# gun|control
# gun|after
# control|after
# he|after
# control|he
# after|he
# after|to
# he|to
# power|to
# he|power
# to|power
# with|power
# to|with
# power|with
# the|with
# to|the
# power|the
# with|the
# with|of
# the|of
# of|of
# course|of
# of|course
# but|course
# of|but
# course|but
# that’s|but
# of|that’s
# course|that’s
# but|that’s
# a|that’s
# course|a
# but|a
# that’s|a
# different|a
# but|different
# that’s|different
# a|different
# different|nothing
# in|nothing
# nothing|in
# in|that
# makes|that
# that|makes
# it|makes
# that|it
# makes|it
# makes|the
# it|the
# other|the
# it|other
# the|other
# hand|other
# the|hand
# other|hand
# the|hand
# the|the
# other|the
# hand|the
# idea|the
# other|idea
# hand|idea
# the|idea
# of|idea
# hand|of
# the|of
# idea|of
# a|of
# the|a
# idea|a
# of|a
# a|at
# at|everything
# everything|down
# and|down
# everything|and
# down|and
# down|it
# and|it
# with|it
# and|with
# it|with
# an|with
# it|an
# with|an
# an|is
# very|is
# is|very
# much|very
# is|much
# very|much
# a|much
# is|a
# very|a
# much|a
# much|of
# a|of
# of|is
# communism|is
# of|communism
# is|communism
# communism|with
# here|with
# with|here
# with|we
# here|we
# need|we
# here|need
# we|need
# to|need
# we|to
# need|to
# get|to
# we|get
# need|get
# to|get
# on|get
# need|on
# to|on
# get|on
# get|and
# on|and
# be|and
# on|be
# and|be
# and|about
# be|about
# politics|about
# be|politics
# about|politics
# and|politics
# about|and
# politics|and
# and|gun
# gun|for
# people|for
# gun|people
# for|people
# he|people
# for|he
# people|he
# knew|he
# for|knew
# people|knew
# he|knew
# would|knew
# people|would
# he|would
# knew|would
# knew|his
# would|his
# his|and
# and|his
# every|his
# and|every
# his|every
# his|he
# every|he
# he|guns
# away|guns
# he|away
# guns|away
# from|away
# guns|from
# away|from
# the|from
# guns|the
# away|the
# from|the
# the|that
# were|that
# that|were
# a|were
# that|a
# were|a
# were|to
# a|to
# his|to
# a|his
# to|his
# world|his
# to|world
# his|world
# his|the
# world|the
# the|the
# the|etc
# these|etc
# the|these
# etc|these
# people|these
# etc|people
# these|people
# were|people
# etc|were
# these|were
# people|were
# were|to
# the|to
# to|the
# the|they
# were|they
# they|were
# they|first
# were|first
# of|first
# were|of
# first|of
# course|of
# first|course
# of|course
# to|course
# first|to
# of|to
# course|to
# make|to
# of|make
# course|make
# to|make
# their|make
# course|their
# to|their
# make|their
# their|is
# is|there's
# nothing|there's
# is|nothing
# there's|nothing
# good|nothing
# there's|good
# nothing|good
# about|good
# there's|about
# nothing|about
# good|about
# it|about
# nothing|it
# good|it
# about|it
# about|was
# it|was
# it|was
# it|it
# was|it
# about|it
# was|about
# it|about
# the|about
# was|the
# it|the
# about|the
# about|of
# the|of
# of|that
# was|that
# of|was
# that|was
# the|was
# that|the
# was|the
# was|to
# the|to
# make|to
# the|make
# to|make
# it|make
# to|it
# make|it
# sound|it
# to|sound
# make|sound
# it|sound
# good|sound
# make|good
# it|good
# sound|good
# it|good
# it|it
# sound|it
# good|it
# was|it
# sound|was
# good|was
# it|was
# it|evil
# was|evil
# evil|and
# stupid|and
# and|stupid
# it's|stupid
# and|it's
# stupid|it's
# not|it's
# and|not
# stupid|not
# it's|not
# the|not
# stupid|the
# it's|the
# not|the
# not|of
# the|of
# communism|of
# the|communism
# of|communism
# it's|communism
# of|it's
# communism|it's
# communism|another
# it's|another
# another|of
# it|of
# another|it
# of|it
# communism|it
# of|communism
# it|communism
# was|communism
# of|was
# it|was
# communism|was
# is|it
# doesn't|it
# it|doesn't
# matter|doesn't
# it|matter
# doesn't|matter
# the|matter
# it|the
# doesn't|the
# matter|the
# name|the
# doesn't|name
# matter|name
# the|name
# or|name
# matter|or
# the|or
# name|or
# the|or
# the|the
# name|the
# or|the
# or|of
# the|of
# their|of
# the|their
# of|their
# their|of
# of|people
# people|as
# a|as
# people|a
# as|a
# as|of
# a|of
# it|of
# a|it
# of|it
# of|it
# it|it
# and|it
# it|and
# it|and
# move|and
# it|move
# and|move
# and|entire
# move|entire
# entire|is
# is|on
# a|on
# is|a
# on|a
# huge|a
# on|huge
# a|huge
# huge|by
# by|ever
# since|ever
# by|since
# ever|since
# the|since
# ever|the
# since|the
# the|and
# the|and
# and|the
# american|the
# and|american
# the|american
# the|left
# american|left
# had|left
# american|had
# left|had
# to|had
# left|to
# had|to
# to|from
# the|from
# from|the
# from|it
# the|it
# it|read
# the|read
# it|the
# read|the
# big|the
# read|big
# the|big
# the|kid
# big|kid
# used|kid
# big|used
# kid|used
# by|used
# kid|by
# used|by
# the|by
# kid|the
# used|the
# by|the
# political|the
# used|political
# by|political
# the|political
# the|when
# political|when
# they|when
# political|they
# when|they
# won't|they
# when|won't
# they|won't
# need|won't
# when|need
# they|need
# won't|need
# him|need
# they|him
# won't|him
# need|him
# need|his
# him|his
# his|will
# be|will
# his|be
# will|be
# will|than
# be|than
# his|than
# be|his
# than|his
# than|poor
# his|poor
# kid|poor
# his|kid
# poor|kid
# he's|kid
# poor|he's
# kid|he's
# kid|the
# he's|the
# attention|the
# he's|attention
# the|attention
# what|attention
# the|what
# attention|what
# he|what
# the|he
# attention|he
# what|he
# doesn't|he
# attention|doesn't
# what|doesn't
# he|doesn't
# he|is
# doesn't|is
# the|is
# doesn't|the
# is|the
# is|majority
# the|majority
# majority|he's
# a|he's
# majority|a
# he's|a
# a|and
# and|at
# his|at
# and|his
# at|his
# of|is
# is|of
# the|of
# is|the
# of|the
# the|class
# class|be
# fine|be
# class|fine
# be|fine
# be|be
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-830ca1010a21> in <module>()
#       2 print("y_train|x_train")
#       3 for i in range(len(y_train)):
# ----> 4     print(vectorToWord(y_train[i]) + "|" + vectorToWord(x_train[i]))
#
# c:\users\brantley\appdata\local\programs\python\python36\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     374             is_child = (not self._is_master_process())
#     375             # only touch the buffer in the IO thread to avoid races
# --> 376             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     377             if is_child:
#     378                 # newlines imply flush in subprocesses
#
# c:\users\brantley\appdata\local\programs\python\python36\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# c:\users\brantley\appdata\local\programs\python\python36\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     389                                  copy_threshold=self.copy_threshold)
#     390             data.group = group
# --> 391         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     392
#     393     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\users\brantley\appdata\local\programs\python\python36\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
#model.save('hamModel.h5')
from keras import models
model = models.load_model('hamModel.h5')
# Out:
# c:\users\brantley\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras import backend as K
get_first = K.function(
    [model.layers[0].input],
    [model.layers[0].output])
get_first([[x_train[10]]])
# Out:
# [array([[0.809374  , 0.73012847, 1.0740963 , 0.5977635 , 0.3303277 ,
#          1.4162319 , 1.4281201 , 0.70244825, 0.31447574, 0.3835917 ,
#          0.66924566, 0.38051653, 1.1392962 , 0.51276386, 0.72495174]],
#        dtype=float32)]

# %%
def magic(word):
    return get_first([[wordToVector[word]]])[0]

# %%
def wordDot(word1, word2):
    return magic(word1).dot(magic(word2).transpose())[0][0]

# %%
dot = {word1 : {word2 : wordDot(word1, word2) for word2 in wordToVector.keys()} for word1 in wordToVector.keys()}

# %%
print(wordDot("hamlet", "lord"))
print(wordDot("hamlet", "the"))
print(wordDot("coming","british"))
print(wordDot("the","in"))
print(wordDot("man","son"))
print(wordDot("a","the"))
print(wordDot("king","henry"))
print(wordDot("coming", "clown"))
# Out:
# 11.788855
# 7.217247
# 29.318314
# 6.8759675
# 12.187774
# 8.254065
# 10.624675
# 9.262323

# %%
def associated(word):
    toSort = [(dot[word][otherWord], otherWord) for otherWord in wordToVector.keys()]
    sort = sorted(toSort, key=lambda x:x[0], reverse=False)
    return [tup[1] for tup in sort]

# %%
associated("hamlet")
# Out:
# ['hast',
#  'thy',
#  'more',
#  'is',
#  'my',
#  'thou',
#  'dost',
#  'no',
#  'clown',
#  'so',
#  'art',
#  'the',
#  "i'll",
#  'wilt',
#  'hath',
#  'too',
#  'his',
#  'that',
#  'be',
#  'how',
#  'to',
#  'she',
#  'find',
#  'doth',
#  'why',
#  'never',
#  'a',
#  'of',
#  'me',
#  'in',
#  'nay',
#  'mad',
#  'cannot',
#  'but',
#  'again',
#  'one',
#  'thing',
#  'nor',
#  'else',
#  'let',
#  'our',
#  'had',
#  'an',
#  'tis',
#  'your',
#  'been',
#  'since',
#  'second',
#  'thine',
#  'for',
#  'not',
#  'when',
#  'should',
#  'mine',
#  'though',
#  'none',
#  'long',
#  'said',
#  'was',
#  'well',
#  'gone',
#  'could',
#  'or',
#  'then',
#  'first',
#  'marry',
#  'forth',
#  'nothing',
#  'her',
#  'any',
#  'now',
#  'honour',
#  'will',
#  'there',
#  'you',
#  'us',
#  'o',
#  'set',
#  'may',
#  'young',
#  'what',
#  'yet',
#  'without',
#  'their',
#  'thus',
#  'till',
#  'they',
#  'hostess',
#  'than',
#  'down',
#  'these',
#  'might',
#  'from',
#  'like',
#  'shall',
#  'stand',
#  'every',
#  'did',
#  'we',
#  'done',
#  'itself',
#  'if',
#  'yea',
#  'them',
#  'percy',
#  'came',
#  'leave',
#  "there's",
#  'here',
#  'were',
#  'horatio',
#  'two',
#  'who',
#  'therefore',
#  'poor',
#  'many',
#  'shame',
#  'those',
#  'good',
#  'can',
#  'being',
#  'ever',
#  'farewell',
#  'very',
#  'hold',
#  'made',
#  'whose',
#  'true',
#  'upon',
#  'give',
#  'keep',
#  'live',
#  'thee',
#  'ye',
#  'him',
#  'after',
#  'three',
#  'meet',
#  'still',
#  'man',
#  'comes',
#  'once',
#  'such',
#  'hear',
#  'put',
#  'where',
#  'eyes',
#  'do',
#  'shallow',
#  'even',
#  'ere',
#  'some',
#  'take',
#  'would',
#  'boy',
#  'cousin',
#  'up',
#  'go',
#  'thousand',
#  'welcome',
#  'call',
#  'lay',
#  'ay',
#  'off',
#  'france',
#  'must',
#  'this',
#  'show',
#  'make',
#  'with',
#  'on',
#  'bardolph',
#  'better',
#  'back',
#  'much',
#  'see',
#  'tell',
#  'dear',
#  'at',
#  'away',
#  'exit',
#  'england',
#  'little',
#  'sweet',
#  'harry',
#  'within',
#  'peace',
#  'come',
#  'brother',
#  'means',
#  'faith',
#  'laertes',
#  'as',
#  'truth',
#  'think',
#  'into',
#  'news',
#  'heard',
#  'it',
#  'both',
#  'words',
#  'himself',
#  'devil',
#  'most',
#  'fair',
#  'same',
#  'out',
#  'indeed',
#  'answer',
#  'chief-justice',
#  'old',
#  'own',
#  'have',
#  'say',
#  "father's",
#  'war',
#  'master',
#  'spirit',
#  'arms',
#  'bear',
#  'eye',
#  'fear',
#  'tongue',
#  'use',
#  'day',
#  'word',
#  'speak',
#  'play',
#  'horse',
#  'cause',
#  'sword',
#  'hamlet',
#  'mother',
#  'about',
#  'men',
#  'myself',
#  'hand',
#  'by',
#  'know',
#  'time',
#  'matter',
#  'he',
#  'night',
#  'fire',
#  'lady',
#  'against',
#  'dead',
#  'power',
#  'friends',
#  'right',
#  'heaven',
#  'which',
#  'death',
#  'great',
#  'part',
#  'end',
#  'earth',
#  'god',
#  'look',
#  'head',
#  'am',
#  'nature',
#  'face',
#  'exeunt',
#  'love',
#  'way',
#  'other',
#  'falstaff',
#  'full',
#  'before',
#  'noble',
#  'i',
#  'life',
#  'blood',
#  'westmoreland',
#  'pray',
#  'son',
#  'grace',
#  'name',
#  'land',
#  'heart',
#  'enter',
#  'prince',
#  'rest',
#  'sir',
#  'henry',
#  'state',
#  'and',
#  'soul',
#  'queen',
#  'majesty',
#  'world',
#  'father',
#  'king',
#  'all',
#  'lord',
#  'john',
#  'coming',
#  'are',
#  'british']

# %%
# Out:
# dict_keys(['the', 'and', 'of', 'to', 'a', 'i', 'you', 'are', 'my', 'in', 'that', 'coming', 'british', 'is', 'it', 'with', 'not', 'this', 'me', 'his', 'for', 'your', 'but', 'be', 'as', 'he', 'thou', 'so', 'have', 'him', 'what', 'lord', 'will', 'shall', 'we', 'our', 'by', 'all', 'on', 'do', 'no', 'if', 'thy', 'good', 'come', 'now', 'from', 'at', 'king', 'sir', 'or', 'thee', 'they', 'let', 'well', 'then', 'more', 'was', 'which', 'an', 'how', 'hath', 'like', 'upon', 'them', 'here', 'there', 'when', 'their', 'enter', 'us', 'would', 'did', "i'll", 'her', 'than', 'go', 'out', 'make', 'may', 'such', 'man', 'these', 'up', 'must', 'why', 'say', 'am', 'give', 'should', 'john', 'yet', 'doth', 'had', 'know', 'where', 'most', 'see', 'too', 'some', 'speak', 'were', 'tis', 'love', 'father', 'time', 'tell', 'one', 'first', 'very', 'who', 'god', 'prince', 'much', 'art', 'exeunt', 'hand', 'down', 'o', 'never', 'can', 'life', 'heaven', 'mine', 'blood', 'away', 'death', 'hear', 'peace', 'think', 'true', 'son', 'exit', 'again', 'look', 'day', 'old', 'she', 'men', 'take', 'before', 'whose', 'great', 'own', 'even', 'any', 'hamlet', 'two', 'thus', 'against', 'made', 'world', 'into', 'heart', 'dead', 'set', 'head', 'england', 'night', 'been', 'faith', 'nor', 'cannot', 'comes', 'hast', 'call', 'sweet', 'could', 'master', 'bardolph', 'indeed', 'eyes', 'those', 'hold', 'fair', 'within', 'name', 'stand', 'young', 'nothing', 'both', 'many', 'might', 'being', 'better', 'falstaff', 'nay', 'part', 'off', 'done', 'fear', 'bear', 'leave', 'till', 'soul', 'little', 'chief-justice', 'other', 'harry', 'thing', 'noble', 'mother', 'play', 'poor', 'said', 'majesty', 'grace', 'france', 'cousin', 'tongue', 'keep', 'news', 'word', 'arms', 'therefore', 'put', 'brother', 'honour', 'right', 'dost', 'face', 'himself', 'lady', 'friends', 'still', 'find', 'queen', 'though', 'ay', 'yea', 'pray', 'thine', 'since', 'full', "there's", 'without', 'land', 'earth', 'boy', 'show', 'about', 'after', 'meet', 'every', 'marry', 'ever', 'dear', 'clown', 'once', 'way', 'matter', 'sword', 'hostess', 'same', 'power', 'live', 'gone', 'spirit', 'truth', 'eye', 'came', 'back', 'itself', 'long', 'war', 'wilt', 'thousand', 'devil', 'percy', 'welcome', 'fire', 'heard', 'none', 'rest', 'westmoreland', 'shallow', 'farewell', 'second', 'words', 'lay', 'answer', 'use', 'forth', 'end', 'horse', 'horatio', 'myself', 'else', 'cause', 'three', 'ye', 'henry', 'state', 'laertes', 'nature', "father's", 'ere', 'shame', 'means', 'mad'])
